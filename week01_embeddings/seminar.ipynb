# %% [markdown]
# ## Practice: Fun with Word Embeddings (4 points total)
#
# Today we gonna play with word embeddings: train our own little embeddings, load one from the gensim model zoo and use it to visualize text corpora.
#
# This whole thing is gonna happen on top of an embedding dataset.
#
# __Requirements:__  `pip install --upgrade nltk gensim bokeh`, but only if you're running locally.
#
# **Please submit this notebook as part of your homework!**

# %%
# download the data:
# !wget https://www.dropbox.com/s/obaitrix9jyu84r/quora.txt?dl=1 -O ./quora.txt
# alternative download link: https://yadi.sk/i/BPQrUu1NaTduEw
# Out:
# --2025-09-28 16:14:22--  https://www.dropbox.com/s/obaitrix9jyu84r/quora.txt?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.70.18, 2620:100:6026:18::a27d:4612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.70.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/p0t2dw6oqs6oxpd6zz534/quora.txt?rlkey=bjupppwua4zmd4elz8octecy9&dl=1 [following]
# --2025-09-28 16:14:23--  https://www.dropbox.com/scl/fi/p0t2dw6oqs6oxpd6zz534/quora.txt?rlkey=bjupppwua4zmd4elz8octecy9&dl=1
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucab030f01c473d41b74cd93f0e9.dl.dropboxusercontent.com/cd/0/inline/CyO0dHqZ_QFgkmVMuLJ5n8PDQ2UjatNVFPh-poXpJp-w92JXSRZc9mMxxssya1n3gLHjzE1cetaepynZ-v97KpDa-BaJXc28DU436rOpmw4qmqOIpQUwFflYVHnB2emAbXA/file?dl=1# [following]
# --2025-09-28 16:14:23--  https://ucab030f01c473d41b74cd93f0e9.dl.dropboxusercontent.com/cd/0/inline/CyO0dHqZ_QFgkmVMuLJ5n8PDQ2UjatNVFPh-poXpJp-w92JXSRZc9mMxxssya1n3gLHjzE1cetaepynZ-v97KpDa-BaJXc28DU436rOpmw4qmqOIpQUwFflYVHnB2emAbXA/file?dl=1
# Resolving ucab030f01c473d41b74cd93f0e9.dl.dropboxusercontent.com (ucab030f01c473d41b74cd93f0e9.dl.dropboxusercontent.com)... 162.125.70.15, 2620:100:6026:15::a27d:460f
# Connecting to ucab030f01c473d41b74cd93f0e9.dl.dropboxusercontent.com (ucab030f01c473d41b74cd93f0e9.dl.dropboxusercontent.com)|162.125.70.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33813903 (32M) [application/binary]
# Saving to: ‘./quora.txt’
#
# ./quora.txt         100%[===================>]  32.25M  9.65MB/s    in 3.7s
#
# 2025-09-28 16:14:28 (8.79 MB/s) - ‘./quora.txt’ saved [33813903/33813903]

# %%
import numpy as np

with open("./quora.txt", encoding="utf-8") as file:
    data = list(file)

data[::500]
# Out:
# ["Can I get back with my ex even though she is pregnant with another guy's baby?\n",
#  'How do oil companies feel knowing oil and gas (fossil fuel, coal) will soon get depleted?\n',
#  'What is the reason of British occupation in India?\n',
#  'About 20 years ago, I believe it was Goodyear, they hammered us with commercials about a new highway surface that would last forever. What happened?\n',
#  'What are five problems every programmer should be able to answer?\n',
#  'What is the difference between a socialist and a Democratic socialist?\n',
#  'What languages are you fluent in?\n',
#  'What does it take to get into SRCC?\n',
#  'In what way I should arrange two convex lenses to get highest magnification? Also tell,what should be their focal lengths?\n',
#  'Are the trams in Lisbon customised for each hill?\n',
#  'Using GCM how does apps like Facebook, Quora, etc send notifications to a single user/device out of so many in the database? How exactly is the server side setup to filter users or devices based on some necessary fields?\n',
#  "How does the US and Canada ensure that Americans and Canadians crossing the border don't extend their visit beyond the six months they are allowed?\n",
#  'Will NEET 2017 be taken in two phases ?\n',
#  "In Hogan's Heroes should Col Hogan have protected Col Klink after Germany's surrender since Klink wasn't really a bad person?\n",
#  'How do I know what martial art is right for me?\n',
#  'What are the suggested system requirements for Sketch 3? Would a MacBook Air work fine?\n',
#  'If the invasion of Normandy failed would Hitler have won the war?\n',
#  'What happens in the brain when you get tired of a song after listening to it a lot?\n',
#  'How are bits and bytes related?\n',
#  'What are some books a 15 year old girl could read to get smarter?\n',
#  "Why don't gods have any last names (surnames) like we do have?\n",
#  'What are the keys to growing your blog audience?\n',
#  'Who loves Greek mythology?\n',
#  'How has technology impacted thinking?\n',
#  'Are moths dangerous to humans?\n',
#  'Is it just me or is Python actually a more difficult language than Java?\n',
#  'How do I stop my dog from crying for no reason?\n',
#  'Is it possible to set up a distributed computing network among all your old computers?\n',
#  'Why does my urine smells like garlic?\n',
#  'What does のだ and んだ mean in Japanese?\n',
#  'What was life in America like in the 1600s?\n',
#  'How do I use Quora in an effective way?\n',
#  'When a man says he doesn\'t want a relationship right now, is that the truth or "he\'s just not that into you"?\n',
#  'I like a girl probably because I was in love with someone who looked similar to her. Should I tell her (the new girl) this thing?\n',
#  'Is denaturation of proteins desirable?\n',
#  'Does it hurt to have sex for the first time? If so, why?\n',
#  'Will CSC and HP benefit from their merger?\n',
#  'At any point since its independence, has any country had the means for a total invasion of the USA?\n',
#  'What is the difference between a comet and an asteroid?\n',
#  "When people who claim to speak for and fight for God get defeated by the enemy, do they ever ponder why God didn't help them out?\n",
#  'How do I convince my girlfriend to lose weight?\n',
#  "Why don't we use wireless technology for everyday use even though we have it?\n",
#  "If my boss owes me money and won't pay me what can I do about it?\n",
#  'How can I pray?\n',
#  "Why did Ronaldo win Ballon d'Or?\n",
#  'Are fresh fruit allowed on domestic flight?\n',
#  'What makes you a good role model?\n',
#  'Why do people become so evil?\n',
#  'Should I send official AP score reports to colleges when applying, or only after getting admitted?\n',
#  'What is photoshopping?\n',
#  'I am in need of a laptop and after researching it I really want to go with a MacBook Pro. Should I buy it now or wait for a new release?\n',
#  'Why Spotify is not available in India?\n',
#  'What is the best way to get traffic to a genealogy website?\n',
#  'Is Esperanto a noun and also an adjective itself. If not, does it have the adjective form?\n',
#  'My wife and I regularly reuse styrofoam cups after washing in the dishwasher. Friends suggest that we are creating a health hazard for ourselves. I understrand styrofoam is considered safe but what about our reuse over and over?\n',
#  'What are the Boston Red Sox?\n',
#  'What should I do about not getting any answers of my questions on Quora?\n',
#  'Is it illegal to own a finger monkey?\n',
#  'Did Doug kill Rachel in Episode 39 (S3E13) of House of Cards and if so, why did he do it?\n',
#  "What's it like to have a job you don't like?\n",
#  'How is an aquifer located?\n',
#  'Can the police of one Indian state arrest a person from another Indian state? Why?\n',
#  'Why do people say "it\'s hard to get into University of Toronto" Is it more difficult than most selective Universities in the US, like under 50% rate?\n',
#  'I want to upload my own made music to youtube and monetize it. How do I prove to youtube that I made this music?\n',
#  'How do I fill my big stomach with zero calories or low calories?\n',
#  'How are Korean names translated to Japanese?\n',
#  'Which is the best camera smartphone under 15k in India?\n',
#  'What is the best time for gym?\n',
#  'What font is used in this picture?\n',
#  'Why is the Indian politician Rahul Gandhi referred to as Pappu in social media?\n',
#  'What is the difference between a simulator and an emulator?\n',
#  'Where can I get the best body spa in Mumbai?\n',
#  'What stores sell dreamcatchers?\n',
#  'Do submarines have cavitation problems? If yes is it resolved?\n',
#  'What are some good free ebooks or pdf files on recording engineering or audio engineering?\n',
#  'How many of you supported to zakir nayak?\n',
#  'Is there any particle that interacts with matter but able to go through an entire planet? Like a photon or a neutrino?\n',
#  'What is the alternative of Backpage?\n',
#  'Which is the best breed of cat for a working couple?\n',
#  'How can I escape from Mexico? I need to start a new life in a different country, Mexico is suffering a terrible crisis and it is affecting us all..\n',
#  'Who should Mulims vote for Trump who wants to ban them or Hillary who wants to bomb them?\n',
#  'How can I boost my auto business?\n',
#  'What does psomí mean?\n',
#  'What is so great about a Turkish towel?\n',
#  'What is mechanical engineer?\n',
#  "What is that one thing you just can't stand?\n",
#  'In mythologies, what do mermaids usually eat?\n',
#  'How can I best prepare for a divorce?\n',
#  'How can we find professors, PhD & masters students from universities of Ukraine who would like to share their knowledge for free to record MOOCs?\n',
#  'Is it normal to bruise after giving blood?\n',
#  'What is the best way to crack gate 2018?\n',
#  "What are good mixers with Jack Daniel's Tennessee Honey?\n",
#  'How would western history be different if Carthage had defeated the Roman Republic in the Punic wars?\n',
#  'Did Hannibal Barca capture any Roman aquila (eagle)? If yes how many? What was its fate?\n',
#  'How does a face become more attractive during weight loss?\n',
#  'What is an example of a platform that leveraged another platform to gain users?\n',
#  'What mistakes have you made in life?\n',
#  'Where can I find all my saved links on my Samsung Galaxy phone?\n',
#  'What are some freelancing tips?\n',
#  'How do I cope with major depression?\n',
#  'Which college I can get with 1577 rank in NEET 2016?\n',
#  "How does someone become a professional sports team's mascot?\n",
#  'How is the IIT food menu in the hostel mess?\n',
#  'Should I get the iPhone 7 or the iPhone 7 Plus?\n',
#  'How good at math is Tony Stark?\n',
#  'What should Vegas tourists not do?\n',
#  'Is it a guarantee that you will lose some senses because of nerve damage after orthognathic surgery?\n',
#  'For which rate can I buy iPhone 5s 64 GB (one year old)?\n',
#  'What was your first date like?\n',
#  "I'm new to table tennis. Which balls should I buy?\n",
#  'What do you think is meant by time travel?\n',
#  'What are must watch Hollywood movies?\n',
#  'What is the scope of CSE with specialization in bioinformatics in India?\n',
#  'I am a 2nd year MBBS student. How should I prepare for NEST scholarship exam?\n',
#  'Why is coming first a big deal?\n',
#  'What is a good substitute for dry mustard powder in a recipe?\n',
#  'How often should I text my long distance crush (every day, two days, once a week)?\n',
#  "Instagram can temporarily disable once in a week. What will happen after a week if I'm not reactivating it yet?\n",
#  'How many marks in twelfth Bihar Board is required for the JEE advance cut off?\n',
#  'How do I convert glasses to contact lens prescription/number?\n',
#  'How do I know if my girlfriend need sex?\n',
#  'I am 33 year old female. How can eliminate my cellulite on my thighs and actually build visible muscles?\n',
#  'What is dark web? What happens there?\n',
#  'What are some useful chemistry/maths tricks I should have for a chemistry interview?\n',
#  'Did Italy get pasta from China?\n',
#  'Where can I have best plaster of Paris in India?\n',
#  'What are some of the best smelling deodorants - for men?\n',
#  'DESCRIBE A SITUATION in WHICH the NET EXTERNAL FORCE ON A SYSTEM IS NOT ZERO, YET ITS SPEED REMAINS CONSTANT?\n',
#  'Will Sagittarius A* eventually suck in everything in our Galaxy over billions and billions of years?\n',
#  'How many type of t shirts are there?\n',
#  'Can upgrade Dell Streak Pro D43 with Baidu Yi to Android 4?\n',
#  'What would you rather be: a big fish in a small pond or a small fish in a big pond? Why?\n',
#  'Is there any Milk Brand in India that provides 100% pure milk without any human contact?\n',
#  'How do I check my IQ for free?\n',
#  'Ancoring script for alumini meet?\n',
#  'Why is the non-aggression pact important?\n',
#  'What is Jio?\n',
#  'Why are black people at the bottom of the economic ladder in white-dominated or historically colonial societies?\n',
#  'What do Native Americans want to be called by others?\n',
#  'Is it possible to retrieve messages even when the phone is in airplane mode?\n',
#  'Can dogs eat cat food?\n',
#  'Can the Supreme Court of India issue writs for a purpose other than enforcement of FRS?\n',
#  'How can I treat this Khyphosis? Will it be treated and spine becomes ideal again?\n',
#  'How do boys express themselves when they are hurt by someone really close?\n',
#  'What is it like to use butt plugs?\n',
#  'What is the actual colour of the sky?\n',
#  'What is the largest lake in India?\n',
#  'What is Harvard 2+2?\n',
#  'What physiological tricks are useful to know?\n',
#  'What do I need to know about technology for an online business?\n',
#  'How can you repair tooth enamel?\n',
#  'Can impedance control be used for improving haptic devices? If so, are there any examples?\n',
#  'I am pursuing Economics Hons from Delhi University. I am confused about my PG. What are the various options present for a PG after Eco Hons?\n',
#  'What are future prospects, after joining bank field as a clerk in the age of 24?\n',
#  'What are some good examples of web based project management software?\n',
#  'Should I take SAT subject tests?\n',
#  'Why do we feel sorry for ourselves?\n',
#  'How did major online businesses raise money for their start-ups?\n',
#  "Why doesn't the government of India remove the system of reservations?\n",
#  'Why am I struggling to get pregnant?\n',
#  'Will President Donald Trump attempt to arrest Hillary Clinton over her e-mail scandal?\n',
#  'Is drinking bubble tea bad for your health?\n',
#  'Show that the set G= {1,2,3,…p-1..} of non zero integer module P. P is prime under multiplication module P is group?\n',
#  'Are there any disadvantages of waking up early?\n',
#  'How is everyone earning millions from home by just using Uber app in mobile?\n',
#  'How Messi is better than Cristiano Ronaldo?\n',
#  'What is document required for loan?\n',
#  "Where are whatsapp 'sent' pictures and 'profile pictures' filders saved in xiaomi redmi phone?\n",
#  'What is the scope of laser in the future?\n',
#  'Why is it offensive to wear traditional dress of cultures that are not your own?\n',
#  'How do I get over a major failure?\n',
#  'Do pear-shaped phones like those on Nickelodeon exist in real life?\n',
#  'As a Christian what is your view on god?\n',
#  'What do common Sikhs think about the demand of a separate Khalistani nation?\n',
#  'What should one take as a souvenir from goa?\n',
#  'Is encryption of email and mobile number in database good option?\n',
#  'There are ego problems in relationships these days. What is the worse incident of break up due to ego problem ?\n',
#  'Does studying make you smarter?\n',
#  'How can I loose 5 kgs weight in 10 days?\n',
#  "What is the reason behind gravity's existence on earth? (Why does it only exist on earth?)\n",
#  'What is the importance of mitosis and meiosis and what are their differences?\n',
#  'Which coaching is best for CAT: TIME, Endeavour or CL?\n',
#  'Is Russia siding with Pakistan?\n',
#  'What are some of the best responses to questions asked in job interviews?\n',
#  'What is the most peaceful time in history?\n',
#  'From which book I should read the extra necessary informations for neet which are not in NCERT?\n',
#  'Does life goes the way we think?\n',
#  'What are Bayesian models?\n',
#  'How do big data databases handle the problem of primary key values running out given that the key is not unlimited size?\n',
#  'Why should you choose a website designing company in Delhi?\n',
#  'How many people applied to ISB YLP in 2013?\n',
#  'Let the stars in the night sky rearrange themselves to write up your name, so that whenever I look up I just find you. What comes to your mind?\n',
#  'How can I make default storage to memory card in lenovo k3 note?\n',
#  'What is the unemployment rate in Lomé?\n',
#  'My friend went abroad for a few days and is trying to make me jealous. How do I react?\n',
#  'What are some songs with great lyrics about loneliness sadness and depression by a female?\n',
#  'How did the Olmec people transport the boulders used for building the Olmec heads considering the fact that they never invented the wheel? Also, How did they carve the stones to make these heads?\n',
#  'I am feeling desperate about my studies what should I do?\n',
#  'How does the Dos attack can be done?\n',
#  'What should I do if I want to become an entrepreneur but I have no idea and money?\n',
#  'Which is the best cleaning service company in Australia?\n',
#  'Can India become corruption free? If yes, How?\n',
#  "Why don't we see once wild, but now domesticated animals in their natural habitats anymore?\n",
#  'Where can I find quality screen printers in Mumbai?\n',
#  'What is the past form of open?\n',
#  'Should I be in touch with my elder brother after his marriage. Will his to be wife like it?\n',
#  'When neutral and ground wires get interchanged, there is flickering in the tube lights. Why?\n',
#  'Is cloud mining even profitable in 2016?\n',
#  'How do I send a text if someone has blocked me on SnapChat?\n',
#  'What hotel in Ooty Hill-station would be safe for unmarried couples, without the harassment of police, hotel staff, and moral police?\n',
#  'T-SQL is for an MS SQL server. On the same lines, which language is used for MySQL RDBMS?\n',
#  'Why do many people hate Alia Bhatt so much?\n',
#  'Should I purchase a Honda Amaze or Toyota Etios?\n',
#  'How much money is spent sourcing real estate development opportunities in New York City?\n',
#  'Could a person feel absolutely nothing if we look each other in the eyes for a longer duration?\n',
#  'How to practice English on Skype?\n',
#  'can i upgrade my laptop with 7200RPM HDD? my laptop model is HP starwars edition 2016 with i5–6200u\n',
#  'Can I do a MA if I have a BSc?\n',
#  'What is dynamic view?\n',
#  'If Objective C is the ideal low-level language for writing iOS apps, why would anyone use Swift?\n',
#  'How does the climate in Europe today compare to one thousand years ago?\n',
#  "How do you enable your ISP's firewall?\n",
#  'Does Putin actually care at all about the future of Russia?\n',
#  'Is Al-Qaeda more right wing or left wing?\n',
#  'What makes Harvard one of the best universities in the world?\n',
#  'What is the difference between a Data Engineer and a Data Scientist?\n',
#  'What is the relationship between voltage and RPM in an AC motor?\n',
#  'What are the managerial prospects for ecommerce?\n',
#  'Do people in China eat walnuts?\n',
#  'What is the best way to rank your website in top searches in Google? Can anyone suggest me some great SEO tips and techniques?\n',
#  'What are the limitation of classical conditioning?\n',
#  'What is a messiah complex?\n',
#  'Why is skydiving expensive?\n',
#  'How often does lightning hit an airplane during a storm and what happens when it does?\n',
#  'What is the best way to remove blackhead scars?\n',
#  'What is it like to have a stepsibling of a different race?\n',
#  "I have a great idea for a women's clothing company. I have the general business plan and concept down, but I have zero experience with creating clothing. How would I go about finding the right avenues and people to get started?\n",
#  'I quit medicine because I was going to kill myself. Should I still hold my head high?\n',
#  'What is a good stock screener for Korean stocks?\n',
#  'What are the job opportunities for software engineers in the government sector (India) with a good salary? What are the age limits and exam names?\n',
#  'What are the ways to find a stolen laptop?\n',
#  'What staple crops grow best in Arabia?\n',
#  'Is 128 a good iq for a nine year old?\n',
#  'How can I learn German?\n',
#  'Why do bus drivers wait at stops even though no else is getting on or off?\n',
#  "If you put 70 people into a room, there's almost 100% chance that two of them have the same birthday. How can you prove/disprove this?\n",
#  'How can I get bigger shoulders?\n',
#  'What is the best short film of all time?\n',
#  'From which website I can download latest and all english songs?\n',
#  'If a CPU can act as a GPU, can a GPU act as a CPU?\n',
#  'Which is a better phone: an Honor 4X or a Lenovo K3 Note?\n',
#  "I'm an atheist in the US, raising my child with no religion. What should I tell her to answer when asked: what is your religion?\n",
#  'Should a 15 year old boy have a job?\n',
#  'What were the Capital Cities of the original 13 colonies?\n',
#  'How reliable are the results of Versant language test?\n',
#  'What is the need of oxidation number?\n',
#  'Is petroleum engineering still a good major?\n',
#  'What is the effect of temperature on coefficient of friction?\n',
#  'Can we assemble and install a MP3 player or iPod by ourselves?\n',
#  "How likely is employment after graduating with an entrepreneurship degree if you know you won't have money of your own to start a business out of college?\n",
#  'Is it better to do a MS in US or a MS in Germany?\n',
#  'Which is easiest job in the world?\n',
#  'Korean drama viki?\n',
#  'How is professional satisfaction in working as doctor with railways through combined medical services if I have done my pg?\n',
#  'Where can you trade commodities online?\n',
#  'Do you believe in first love?\n',
#  'Can we use hair gel for beard?\n',
#  'Why do some people prefer texting to phone-calling? Why do so many people prefer using their phones for texting instead of talking?\n',
#  'Are Sikhs more religious and more generous than Christians?\n',
#  'How can one do a thought experiment?\n',
#  "I'm traveling to London solo and want to meet cool people. Should I stay at a hostel or book something on Airbnb?\n",
#  'What are the pros and cons of thr Unity 5 Engine?\n',
#  'What is Kai the robot?\n',
#  'What are some prerequisites for a democracy to be successful?\n',
#  'What is NETserver.app and should I allow it to accept incoming network connections?\n',
#  'Where can I have paid sex in Mumbai?\n',
#  'What is Diaspora?\n',
#  'Should I hate my ex-girlfriend for cheating on me?\n',
#  'Is metasearch in travel a substantial business model?\n',
#  'Is Eminem better than Jay Z? Why/why not?\n',
#  'Who were the famous british restaurants owner?\n',
#  'What are the contributions of Islamism to the world?\n',
#  'Is college football played under Canadian football rules popular in Canada?\n',
#  'How do I decorate my bedroom with a 1981 theme?\n',
#  'The Earth is not exactly spherical. Why?\n',
#  'What is the best way to live a life?\n',
#  'How can I find HIDDEN wasp nests and eradicate them?\n',
#  'What does it feel like to be a common North Korean citizen?\n',
#  'Is food addictive?\n',
#  'Most frequently asked topics in arithmetical aptitude?\n',
#  'How serious are the effects of human population on climate change and natural resources?\n',
#  'What are the good websites to learn C programming for begineer?\n',
#  'Why do we forget dreams so quickly?\n',
#  'How is the M.A. political science department at JNU?\n',
#  'How can I remove spiders from my house?\n',
#  'If I insert Jio sim in Lumia 535 will it not work at all?\n',
#  "What do you think of the name 'Zephyr' for a girl?\n",
#  'How much does it cost to the Indian government in making of 2000 rupees note?\n',
#  'How is Apple innovative?\n',
#  "What's the most predictive multifactor model for stock selection a money manager can subscribe to?\n",
#  'Are there modern-day hippies? Where are they and how do they live?\n',
#  'Corporate Structures: What is the difference between board of directors, Managing director, Chairman, Promoter, Founder, Co-founder, Owner, President?\n',
#  'Why should pregnant women eat pomegranate?\n',
#  'What is the driving force of your life?\n',
#  'What is the difference between interpretation and translation?\n',
#  'How do petrol pumps earn?\n',
#  'Subscribe data protection through virtualization?\n',
#  'What is the difference between Chinese and western culture?\n',
#  'What is any extra charge if I deposit cash through an ATM branch of an SBI or any other bank?\n',
#  'What are the best advertising banner companies?\n',
#  'How does computer science and electrical engineering programmes at IIT Delhi compare in terms of placements? Answers with numbers (and not just CSE>EE) are expected.\n',
#  'According to believers, what is the "afterlife"?\n',
#  'What is it like to be beautiful? Not just pretty or hot, but the kind of almost objective beauty that people are sometimes intimidated by?\n',
#  'What does "capitalism" and "laissez-faire" mean?\n',
#  'What are the essential skills for a electronic engineer?\n',
#  'Can an email which has been deleted from the trash box of Gmail be retrieved?\n',
#  'Why does my stomach feel cold inside?\n',
#  'How good is a strawberry kiwi Jell-O?\n',
#  'What do the members of the Legislative Assembly do?\n',
#  'What are some mandatory rules that every citizen of your country must has to follow whether you like it or not?\n',
#  'Do employees at International Speedway have a good work-life balance? Does this differ across positions and departments?\n',
#  'What are the different platforms for CSE students?\n',
#  'What are some tips on making it through the job interview process at Artisan Partners?\n',
#  'How does Dream11 make money?\n',
#  'What are the security vulnerabilities in HTTP?\n',
#  'What is storage area network?\n',
#  "What's it like meeting Azim Premji?\n",
#  'What is your review of Harvard Sustainability Certificate?\n',
#  'Why is Narendra Modi not fluent in English?\n',
#  'What is a Punnet square? What are some uses of Punnett squares?\n',
#  'Can Stress cause rectal bleeding?\n',
#  'Who will win the man Booker prize 2015?\n',
#  'What is the IUPAC names of the following compounds?\n',
#  'When will ICSE 2017 re timetable be declared?\n',
#  'If you are single, after what age is it better to be single for the rest of your life?\n',
#  'What format yields the best quality: WAV or MP3?\n',
#  'What percentage of international students pay for their PhD in Australia?\n',
#  'Where can I get quality services for safety switch installation in Sydney?\n',
#  'How can you change the IMEI of an iPhone?\n',
#  'How do you say the same thing in many different ways?\n',
#  'Is the universe expanding day by day?\n',
#  'When should I take the eLitmus test and how should I prepare for it?\n',
#  'How can one hide his/her private apps in android phone?\n',
#  'What do South Indians and North Indians think about Maharashtra?\n',
#  'Is Ruby on Rails dead?\n',
#  'Is masturbating bad for girls?\n',
#  'Are Wolverine 1000 Mile boots durable?\n',
#  'What are the best ways to become rich quickly?\n',
#  'Which posts are in mpsc?\n',
#  'What are good sites for resume writing/editing in india?\n',
#  'Why do we see colors when we close our eyes?\n',
#  'What is Google +1?\n',
#  'How do I prove the independence of a product of random variables?\n',
#  'Sunglasses: what are the best customer acquisition channels for such product in the USA?\n',
#  'What is your review of MySQL Performance?\n',
#  'Why do you get cramps when you get your menstrual period?\n',
#  'What is the most nutritionally-dense food, with the least calories?\n',
#  'Is it safe for a 21 year old Indian to travel alone to Bangkok?\n',
#  'Why do people hate Common Core standards?\n',
#  'What type of weather is usually associated with a cold front?\n',
#  "Formula one - Why did Ayrton Senna's head move after his crash? How did his injuries kill him and how quick was his death?\n",
#  'Is following hadith together with the Qur’an compulsory for Muslims?\n',
#  "I'm 20 years old and I have $15,000 from working that I want to invest. What should I do?\n",
#  'How did Thrillist get to 2 million subscribers?\n',
#  'What are some examples of imprinting in animals?\n',
#  'What are some good gift ideas for my counsellor?\n',
#  'What are the pros and cons of fishing with tube flies?\n',
#  'Is it still a good idea to move to Austin from the Bay Area?\n',
#  'Where can I find designer fashion jewellery?\n',
#  'How do I make a person care for me?\n',
#  'How many times have the SF Giants won the World Series?\n',
#  "I am 26 year old but still don't have full cheek beard. What should I do to have full face beard?\n",
#  'How long can one be a software engineer?\n',
#  'What are the placement statistics (average salary, placed %) for NIT Warangal EE?\n',
#  'How much money do you need to earn to live a comfortable life in Japan?\n',
#  'I like watching movies. Is there any career there?\n',
#  "In 'The Scarlet Letter', why was Chillingworth called a leech?\n",
#  'Are Chinese taking over the world?\n',
#  'Is there a union with plans to hold union organizing skill training for low-wage employees making products offshore?\n',
#  'Have u ever been attracted to someone of same gender?\n',
#  "How do I tell my parents that I don't believe in god?\n",
#  'Half of people believes?\n',
#  'Do we need "Share a Comment" features on Facebook, What do you think?\n',
#  'How do you put a bit of sense in stupid?\n',
#  'How is the TSA unconstitutional?\n',
#  'How do you calculate dimensions?\n',
#  'How do I find someone by only first name?\n',
#  'My blood pressure was 160/86 for three months. My doctor finally had to give me four medication. Is there a chance to lower my blood pressure?\n',
#  'How can you get rid of a boil that is under the armpit?\n',
#  'What are some funny examples of oxymoron?\n',
#  'What is the future and life in merchant navy if I join?\n',
#  'Should I still consider to study in the US with Trump as president?\n',
#  'Who are some excellent underground hip-hop artists specifically local to your area that most people would not know about?\n',
#  'How far can you go on one charge on a hoverboard?\n',
#  'If the civil war occurred today who would win?\n',
#  'What is difference between 4G and LTE?\n',
#  'What is the best MIDI keyboard?\n',
#  'Why do birds lay different coloured eggs?\n',
#  'What are the best episodes of Pretty Little Liars season 4?\n',
#  'How do I solve this statistics question on mean?\n',
#  'In some Japanese manga about sports or fighting, why are American opponents often portrayed as being mean and lacking sportsmanship?\n',
#  'In what ways is Hillary Clinton corrupt?\n',
#  'What will Hillary Clinton do about climate change?\n',
#  'Why should I not do a job in TCS?\n',
#  'Is the Pearl Harbor 1941 attack a hoax? Or not?\n',
#  'What is port 8080 used for?\n',
#  'How long is a business considered a "start-up" for?\n',
#  'How does the average Japanese view the Nanking Massacre?\n',
#  'How do I calculate the maximum buffer capacity?\n',
#  'Do you buy survival portable water filter?\n',
#  'How do I spell etc.?\n',
#  'Is "G" based on real events?\n',
#  'Did later Mughal emperors (like Alamgir or Shah Alam) speak English?\n',
#  'Are Kayak tickets refundable?\n',
#  'What is the easiest way of finding out if a song is a cover version?\n',
#  'What is the difference between PayPal, Apple Pay and Google wallet?\n',
#  'What are the most interesting products and innovations that Liberty Interactive is coming out with in 2016?\n',
#  'Did Chanakya get married?\n',
#  'What does the GRE mean by "once every 21 days, up to five times within any continuous rolling 12-month period (365 days)"?\n',
#  'What is the advantage of using Google cardboard?\n',
#  'Why is  HTTP protocol called stateless protocol?\n',
#  'Can I apply for a PR in Australia while I am studying in Australia for a masters course on a student visa 573? I have met the criteria of 65 points.\n',
#  'What is some witty name for a 24hours food joint?\n',
#  'What are the requirements to apply for the Malaysia work permit?\n',
#  'Why was cotton known as "king cotton"?\n',
#  'What is the chemical formula of methyl nitrile?\n',
#  'Can the "seen" mark in Facebook chat be turned off?\n',
#  'How come a girl turned down a foot massage in person?\n',
#  'Theism: What is the most convincing argument to become a theist?\n',
#  'Is the Earth moving? How fast?\n',
#  'What does it mean when I get an update from Quora saying my answer was moved?\n',
#  'What is the monomer of amino acids?\n',
#  'Can China actually surpass USA as the superpower?\n',
#  'What would the world be like if the industrial/agricultural revolution never happened?\n',
#  'Where can I catch a Tauros in Pokémon GO?\n',
#  'Why did Macedonia conquer Greece?\n',
#  'How do you start a Wikipedia page about a company?\n',
#  'How can you start believing in yourself?\n',
#  'What do radio station call letters mean?\n',
#  'What could be the max speed of my bike with this specs (72V 70 amp with 2000 watt motor)?\n',
#  'Why does Quora allow people to merge my question with others without my consent?\n',
#  'What individuals and events in history are a source of pride for Japan?\n',
#  'What are the arguments for pro or anti monarchy in Britain?\n',
#  'What is Projects?\n',
#  'What was the production of artwork intended for in Hawaii and how is it compared to the one intended for in Alaska?\n',
#  'What business I can start with 20000 INR in Punjab (India)?\n',
#  'How do you build a bench press?\n',
#  "Why can't nuclear waste be recycled?\n",
#  'What is the difference between an "account manager" and "accounts manager"?\n',
#  'What motivates you to do good job?\n',
#  'Can we control our dreams? Can we dream what we wanna dream about?\n',
#  'How do ideal with back log while preparing for IIT?\n',
#  'What is the difference between MPPT and PWM?\n',
#  'What is the difference between direct vernier and retrograde vernier?\n',
#  'What are the most common causes of fires in houses?\n',
#  'What did Jaime see in Cersei which made him love her so much?\n',
#  'Can I deposit money at a SBI branch which is not my home branch?\n',
#  'What is the minimum marks required in Neet exam for getting MBBS seat?\n',
#  'What led FOX to accept New Girl on the first place?\n',
#  'Is Democracy better than communism?\n',
#  'What are the dangers of alpha radiation? Why are they dangerous?\n',
#  'Which particles are cold dark matter?\n',
#  'How do I opt out from Life insurance investment?\n',
#  'When writers read great writing by other writers, do they feel motivated, competitive, envious, or despairing at ever being as good?\n',
#  "What is the best way to ruffle someone's feathers?\n",
#  'I am an Indian commerce student studying in 12th. After my 12th, if I want to learn Android app developing, website making and online business, which career option should I choose?\n',
#  'What is the remedy for prolonged knee pain?\n',
#  'What is a Marketing Coordinator?\n',
#  'I wan to enter into an RSI. How can I enter into an RSI?\n',
#  'What are the merits of Oppo phones?\n',
#  'What would happen if gene expression was not regulated?\n',
#  'What are the sensors available in Acer Liquid Z630S Android Smart phone by using CPU-Z App?\n',
#  'What similes does The Iliad have?\n',
#  'What are the pros and cons of merging the Railway budget with the Union budget ?\n',
#  'To what extent does your undergraduate college have an influence on med school acceptances?\n',
#  'How much money does a 9-year experienced engineer make in Riyadh?\n',
#  'How can I become famous one day?\n',
#  'How lazy can you get?\n',
#  'I want to update kyc in SBI bank if I already have another account wirh same name and id in SBI itself?\n',
#  'What is the fastest production car?\n',
#  "Do we have great people who aren't patriotic?\n",
#  'Is xenophobia a form of racism?\n',
#  'What is the hiring process like at GitHub?\n',
#  'Why are ticks so prevalent compared to years ago?\n',
#  'How do I work out when I have no motivation to work out?\n',
#  'What is the population of the USA?\n',
#  'How are non-identical twins made? How does that differ from identical twins?\n',
#  'Do nuns masturbate?\n',
#  'Could you recommend me a book for acid-base reactions in organic chemistry?\n',
#  'What is Technical information about now a days studies and courses?\n',
#  'What are good research topics in machine learning in 2016?\n',
#  "What is defined ('BASEPATH') in codeigniter?\n",
#  'What are the career options after graduation (B.sc Computer Science) ? . I like Computers, pschylogy and defense services\n',
#  'What is it like to be an engineer?\n',
#  'What is it like to be an attractive woman?\n',
#  'What are some fun things to do when bored?\n',
#  'What does a green dot by the phone icon mean on Messenger?\n',
#  'How competitive is the hiring process at Cubic?\n',
#  'How well has Bill de Blasio managed NYC?\n',
#  'Is there a Jerry Lee Lewis tribute band in Ferriday?\n',
#  'What are the things one can do after an M.Tech in software engineering (from BITS Pilani) inside and outside of India?\n',
#  'My hair is falling. What can I do to prevent this?\n',
#  'What individuals and events in history are a source of pride for Albania?\n',
#  'What are good topics for research?\n',
#  'What is the difference between Windows 7 Professional and Windows 7 Ultimate?\n',
#  'What should I do as an undergraduate to get into top EE/CE/CS PhD programs?\n',
#  'How do you make a dynamic webpage in Express?\n',
#  'How do I transfer from an anna university affiliated college to US university after 4 semesters?\n',
#  'What app will let me download free songs on my iPhone?\n',
#  'How can I recover a lost Battlefield: Bad Company 2 serial key?\n',
#  'If you had 100 billion dollars and you knew that you would always live like a multi-billionaire, what would be the first thing that you would do with that money?\n',
#  'Is it ever OK to wear brown shoes with black pants?\n',
#  'Is there any negative mark for IAS exam prelims and Mains?\n',
#  'What are some great free websites to find keywords for YouTube videos?\n',
#  'How do you become pretty/attractive?\n',
#  'On Amazon, can I purchase with intent to return? There\'s a return option which says "no longer need it" which then charges me a restocking fee etc.\n',
#  'What are the top 10 films every film lover should see?\n',
#  'What should be my CAT score to get into IIM A,B or C with this profile?\n',
#  'Is six hours of sleep enough for a 11 year old?\n',
#  'How can the Cooum River be restored?\n',
#  "Why don't Muslim men wear hijab?\n",
#  'What is the value of a Antonius Stradivarius Cremonensis Faciebat Anno 1713?\n',
#  'How do Private Equity Funds work in film?\n',
#  'Will Google Allo allow users to create their own bots/assistant?\n',
#  'How can I make money off of $1000 in the stock market?\n',
#  'When is the last time you felt like you were the happiest person in the world?\n',
#  'Is it disrespectful to laugh hysterically in a public place?\n',
#  'What does it mean if my new girlfriend talks a lot when I meet her what does it mean? Is this a good thing? Also she talks a lot of her problems\n',
#  'What does the expression "the whole nine yards" mean?\n',
#  'What are the pros and cons of owning an EV (electric vehicle) in Honolulu?\n',
#  'Where can I play table tennis in Dubai?\n',
#  'What should be the stratergy to be a great coder?\n',
#  'What is the meaning of the Telugu word prayam and tamakam?\n',
#  'Why should guys always put more effort in a relationship?\n',
#  "Should I leave my depressed girlfriend because she told me she wants to end it because she doesn't want to hurt me anymore?\n",
#  'Having sex with two women same time?\n',
#  'I am a home-maker. I have not studied much, but I want to earn money without going out. How can I earn money from home?\n',
#  'What do you like most about Internet?\n',
#  'What is the difference between shia and sunni method of collecting Hadith?\n',
#  'How does the vinyl player work?\n',
#  'Should I do a Thiel Fellowship or college?\n',
#  'Which industry should I target for a stable career?\n',
#  'What material should I use to pass the C2180-377 exam?\n',
#  'How do I bring up a 3.4 GPA?\n',
#  'Is it legal for rental company, to track my rental car location using GPS without my notice?\n',
#  'What is some conventional wisdom that has been proven false by scientific scrutiny in the last 50 years?\n',
#  'Is C++ a good language for machine learning?\n',
#  "I'm doing first year electrical engineering. Will I have time to learn to code and will it help me in the future as I'm not a CS student?\n",
#  'What are some facts about India that Indians are generally unaware of?\n',
#  'Can a NRI deposit 2.5 lakhs without a PAN card?\n',
#  'What are the pros and cons of being a girl in India?\n',
#  'How do I create a live chat module through Javascript and a web method in C#?\n',
#  'What do you do to spy on Facebook messages without a target phone?\n',
#  'How are Corn Nuts (corn gone wrong) made?\n',
#  'Can we use CSS styles on Javascript variables?\n',
#  'Were India and China part of Turkey at any point of time in world history?\n',
#  'What is the best way to soft boil an egg?\n',
#  'How did Kakashi get the Sharingan?\n',
#  'How do I start to read Word Power Made Easy by Norman Lewis?\n',
#  "I'm 13.5 years old. My height is 180cm. How tall am I going to be when I grow up?\n",
#  'What are the ways to start investing in Share Market?\n',
#  'How do I know when my spouse is having an affair with someone else?\n',
#  'Is religion brainwashing?\n',
#  'What is polytropic process?\n',
#  'How can a scab inside an ear be treated?\n',
#  "How do Domino's make their pizza?\n",
#  'What secrets do women not want men to know?\n',
#  'How do I create ECG graphs using data points I had collated from electrodes directly, do we have an open source software?\n',
#  'I really want to become a pilot. I am 15 years old and I want to know the steps to becoming a commercial pilot?\n',
#  "Do you think Indian government should respond fast and strictly to latest terror attack by Pakistan's terrorists?\n",
#  'What is the best language to teach concepts and good code?\n',
#  'Social Sciences: What is the difference between sociology and anthropology?\n',
#  'What do you think about attn.me?\n',
#  'Is there still a demand for market research focus group moderators? Or has it decreased?\n',
#  'What is the relation between sun and eyes per Vedas?\n',
#  'Why is getting an education important?\n',
#  'My boyfriend avoided me for half a month but when I decided to break up with him, he became affectionate all of a sudden. What does this mean?\n',
#  "Gary Johnson is the Libertarian candidate for President. He's polling relatively high. Does he hurt Trump or Clinton more in the general election?\n",
#  'What makes Hamilton the musical so great?\n',
#  'How will a Trump presidency affect the rest of the world?\n',
#  'Why do Muslim-majority nations seem often to be at war with their non-Muslim neighbors and internal minorities?\n',
#  'What is the best open source software in Indian banking?\n',
#  'What is the most successful treatment for any cancer?\n',
#  'How do I report child neglect in North Dakota?\n',
#  'How do you fix a broken finger that healed crooked?\n',
#  'Where does the friction act when lizard move up the wall?\n',
#  'Why do Sphynx cats leave brown marks?\n',
#  'Can anybody get creative ideas for writing and composing music? And if so, how?\n',
#  'How has DMT changed your life?\n',
#  'Who has gotten a job by applying through LinkedIn?\n',
#  'How can I Self Publish Book in Austria?\n',
#  'What is perdictive coding?\n',
#  'Why is lambswool itchy?\n',
#  'How did Apple change the world?\n',
#  'Should I dump my girlfriend because she still cares for her ex boyfriend?\n',
#  'What is the maximum MVA that a 66kv transmission line supply?\n',
#  'What is the spiritual value of Halloween?\n',
#  'How do you get brands to send you free toys to review on YouTube?\n',
#  'Pull three blocks of same mass connected with each other, with F force and the acceleration is A so how much force will act on the middle one?\n',
#  'What is the reciprocal of a smiley face?\n',
#  "Occasionally I feel a sharp pain near where I think my heart is and when I inhale it's painful, but goes away after a few seconds. Is this a bad sign?\n",
#  'Which language is harder to learn: Japanese or Chinese?\n',
#  'What are the hottest startups in the Seattle in 2015?\n',
#  'Objectively, how good of a band is Green Day?\n',
#  'How are the placements at Manipal University Jaipur?\n',
#  'How are underground metros built?\n',
#  'Why is it so uncomfortable to eat with a palate expander?\n',
#  'What are some of the must-read books in Malayalam?\n',
#  'How can music help people with OCD?\n',
#  'What are crown and pinions used for?\n',
#  'I lost my social security card a few months ago, what should I do?\n',
#  'How do I prepare for class 9 exams?\n',
#  'Who is the founder of zero?\n',
#  'Why can’t we ever prove or disprove the existence or non-existence of God?\n',
#  'What are the pros and cons of Ruby on Rails?\n',
#  'How do you say prayer in Spanish?\n',
#  'What is StartRating.com?\n',
#  'What are some places to camp near a water body in India?\n',
#  'What is the salary of the PM of India?\n',
#  'Which is the best country for business?\n',
#  'Is Google Adwords dropping  Google+ from Search Ads?\n',
#  'Why is valuing your family important?\n',
#  'Textbooks for "relativistic quantum mechanics"?\n',
#  "What is the average age of MOOCs' student?\n",
#  'What are de broghlie matter wave?\n',
#  'What is the process by which water travels along the cell wall during transpiration?\n',
#  'What is the example of analogy?\n',
#  'What is the difference between a low pressure and a high pressure pump?\n',
#  "What happened to Ritchie Valen's family after Ritchie died?\n",
#  "My mom doesn't like my girlfriend and is always talking disrespectfully about her. My girlfriend says I need to stand up for her. What should I do?\n",
#  'What is 1/2+1/2?\n',
#  'Which loan pay off first home loan personal loan or gold loan?\n',
#  'I am planning to start an online grocery store. What are the steps to be taken to start the online grocery store?\n',
#  'Why do people find me intimidating?\n',
#  "I'm 35. How much money should I have saved for retirement?\n",
#  "Will America lose it's power, properity, and prestige under President-elect Donald Trump?\n",
#  'Is Odisha developing?\n',
#  'How do banks design their financial products?\n',
#  'Which are the best universities in USA?\n',
#  "Why doesn't Indian government care about its poor people?\n",
#  'What are some places that I can visit in Chennai with my girlfriend?\n',
#  'Why do you think transparency needed in democracy?\n',
#  'What is your review of PAN Card?\n',
#  'How can I fit into the German lifestyle?\n',
#  'International awards of Shahrukh Khan?\n',
#  'Why would someone want to be president of the United States if all it is is stress and criticism?\n',
#  'How difficult is it to be a doctor?\n',
#  'What is the difference between the Cisco Catalyst 2960 Series and Cisco Catalyst 296-S Series?\n',
#  "What dishes best represent Canada's history and culture?\n",
#  'Which states are considered to be securely BJP states?\n',
#  'How can I find Launchpad on my MacBook Air?\n',
#  'Can I make a living by selling handmade?\n',
#  'I bought a second hand Hyundai i10 from Chennai. The A/C is making more noise while on. How much it will cost to replace the whole unit?\n',
#  'How do I keep a very low-profile at work?\n',
#  'I have scored 138 in NEET 2016, I am SC candidate, what can be my rank or can i get admission to any private college?\n',
#  'How can I get rid of a depressing job?\n',
#  'What time gap should I maintain between yoga and having food?\n',
#  'What are some mind-blowing war stories that were passed down in your family?\n',
#  'How much salary is enough to live comfortably in Saudi?\n',
#  'Where is the best film school?\n',
#  'How should I propose my girlfriend mathematically?\n',
#  'How do I foster a learning attitute in my 8 year old kid?\n',
#  'If we were completely able to control our emotions and feelings, do you think it would make our lives better or worse? Why?\n',
#  "I have taken the CSC math group. I don't want to go to science fields like engineering, etc. What can I do after my 12th?\n",
#  'Is corruption mixing things up?\n',
#  "When is Rex Tillerson's confirmation hearing?\n",
#  'Do cats and dogs prefer to be domesticated?\n',
#  'Why is Narsingh Yadav banned for 4 years?\n',
#  'Why did animals evolve to need sleep?\n',
#  'Is it true that shia is not part of Islam ?\n',
#  'How do I wish someone a happy birthday anonymously?\n',
#  'What should be the package of a 4 yesrs it inside ssles person?\n',
#  'What is the scope of biotechnology in the USA?\n',
#  'Can we save the earth from becoming another mars by global warming?\n',
#  'How do I perform well in an interview of IAS?\n',
#  'What are some things to do when confronted by a hostile force?\n',
#  'How many phyla are there within the Archaea? What are the arguments for?\n',
#  'The best Beatles song for scientist or philosopher to reminisce for the time of a tea break?\n',
#  'How do I unarchive a conversation on Facebook Messenger?\n',
#  'Can we do MBA after be?\n',
#  'How many is too many illegal immigrants and how will America preserve its borders and identity as a nation?\n',
#  'What are the best examples of story in marketing?\n',
#  'When a motor vehicle speed is limited by law, then why do manufacturers design cars that can go significantly above that limit?\n',
#  'Should I take AP bio or AP environmental science?\n',
#  'How can someone invent a time machine?\n',
#  "Do guys appreciate a woman who's forthright about her feelings?\n",
#  'What is it like to be a sociology professor?\n',
#  'What is the hybridyzation on cl in CLO2 minus?\n',
#  'If you block someone on Quora, can they still comment on your board posts?\n',
#  'Music Recommendations: What are some good karaoke songs for baritone singers?\n',
#  'What was combat like in the Vietnam war?\n',
#  'Which is better AMD radeon r5 m335 4GB or Nvidia Geforce 940m 4GB graphic card for laptops?\n',
#  'How do tech startups file patents?\n',
#  'How do you do an assisted chin-up?\n',
#  'What is the difference between sociology and journalism?\n',
#  'My cocubes score is 518. can I expect any call from IT companies?\n',
#  'How do you counter the impostor syndrome in grad school?\n',
#  'Why is Two Sigma Investments so successful?\n',
#  'What are the advantages and disadvantages of COPYWRITING?\n',
#  'Can anyone give an idea related to project work on microprocessors?\n',
#  'What are some of the best extempore topics?\n',
#  'What are known health risks associated with genetically modified foods?\n',
#  'How much is one million and one billion in lakhs and crores?\n',
#  'What is the definition of tone of the movie?\n',
#  'What type or genre of music is this and how can I find more music similar to this one?\n',
#  'Do women like being gang banged?\n',
#  'For how many days can a person survive without food?\n',
# ...
#  "What's an alternative site to bookzz.org?\n",
#  'How do I look at a private user account on Instagram?\n',
#  "What's the most effective way to get started with Deep Learning?\n",
#  'Are people allowed to chew gum while they are fasting?\n',
#  'What happens to the market price of shares when bonus shares are issued?\n',
#  'What is the best excuse to bunk a class?\n',
#  'How should I get health insurance?\n',
#  'Can hearing loss be contributing to my age 94 mother having more difficulty speaking?\n',
#  'What is the spin quantum number and what is its value?\n',
#  'What is the function of choke in fluorescent lamps?\n',
#  'How did/do you learn design?\n',
#  "What's the best extra virgin olive oil?\n",
#  'Is GDS (Worldspan, Sabre and Amadeus) knowledge still important to whoever wants to work in tourism professionally? Why?\n',
#  'Why do queen ants have wings? How often do queen ants reproduce other queen ants?\n',
#  'How did Elon Musk work for 100 hours a week for more than 15 years?\n',
#  'How do I get rid of all sodium in my body?\n',
#  'What is oriental?\n',
#  'Why is menu planning so important?\n',
#  'Will EU fall apart in the next decade?\n',
#  'How we can define loneliness?\n',
#  'Are there any Masonic lodges in India that are affiliated to the Grand Orient?\n',
#  'Do small social movements necessarily have less influence on politics than larger movements?\n',
#  'How do I solve problems of boats and streams?\n',
#  'Why is it called Microsoft Excel?\n',
#  'How do buzzers operate?\n',
#  'Do all sociopaths have high IQs or can they also be average and below average intelligence?\n',
#  'What do Greeks think of Brexit?\n',
#  "What's the best pair of headphones under $100 for gaming on the Xbox One?\n",
#  'What is the inheritance tax rate in Texas? Does this differ from state to state?\n',
#  'What is the best way to lose 40 pounds in 3 weeks?\n',
#  'Is it right for me to question so much when I read the Bible?\n',
#  'As a motorcycle rider, how do you switch to riding a quad without steering in the wrong direction (due to your brain being "wired" to counter steer)?\n',
#  'How do you make a spicy crunchy tuna roll?\n',
#  'How do I score above 700 in GMAT? I have been preparing since two months and lately scored only 460 and I have been studying 6 hours everyday?\n',
#  'What is best leader version of you?\n',
#  'What makes a batter strike out a lot?\n',
#  'Does Allah know the proper punishment for the sins you have done? If I ask Allah for forgiveness after my punishment, will he gladly accept my wish and not punish me for my actions unless I do them again?\n',
#  'Should I choose Wharton or MIT Sloan for a full-time MBA?\n',
#  'Why should I learn a functional programming language?\n',
#  'Which one is more important to you: to love or to be loved?\n',
#  'How much electricity bill is pending on govt. Organisations in UP?\n',
#  'When should I replace my water heater?\n',
#  'What are some summer programs similar to RSI where there are ample opportunities to conduct research?\n',
#  'What are some tips on making it through the job interview process at Journey Energy?\n',
#  'What will happen to Singaporean banks if 40% of their Indonesian assets flown back home ?\n',
#  'How does Quora target users?\n',
#  'How can you convince me to read nonfiction?\n',
#  'Do psychopaths procrastinate?\n',
#  'How do banks make money from prepaid card?\n',
#  'What specific factors, if any, led to Munchery receiving significantly more funding versus its competitors (Sprig, etc)?\n',
#  'When will religion cease to exist?\n',
#  'Why do my antibiotics cause constipation?\n',
#  'Why do some people believe Republicans are evil?\n',
#  'What is the value of 0?\n',
#  'Based on the latest Rand study, should the U.S. provoke a limited hot war with China now, before it loses the firm upper-hand in 2025?\n',
#  'What is the growth strategy of Uber?\n',
#  'What are the best sex sites?\n',
#  'What flower/s should I draw next? I want to draw a flower not-so-basic and eloquent. Thanks,\n',
#  "Religion as a whole teaches love and compassion. Even if a god doesn't exist, why do people resist the thought of a religious mentality?\n",
#  'What is the difference between mutually exclusive events and independent events?\n',
#  'How do I raise seed money for a brilliant fintech idea?\n',
#  'What is JSON?\n',
#  'What would it take for you to vote for the US President?\n',
#  'Why is the first 20 minutes usually red coloured, on a watch face?\n',
#  'What is mean by infrastructure?\n',
#  'If you had a billion dollars and never had to work again in your life, what would you do with your life?\n',
#  'How do I use import node.js in Unity 3D?\n',
#  'How can I create a katana in Photoshop?\n',
#  'Pokemon go hack?\n',
#  'What is sociolinguistics?\n',
#  'What is the difference between tablets and pills?\n',
#  'Which country has the most bald people?\n',
#  'What is a market space?\n',
#  'How can I find a job in singapore from India?\n',
#  'Can tortoises eat blueberries? Why?\n',
#  'How do you get them to stop picking on you?\n',
#  'Is actualtests.com a scam?\n',
#  'What are the biggest problems your agency faces?\n',
#  'Is there anything you can take to pass a urine test for meth?\n',
#  'What would have happened if Jon Snow was a blonde?\n',
#  "Why was I born? What am I? Why wasn't I born this person or that person, or a lion or dog or any other animal, whether in the present, future or past?\n",
#  'What is the best "Last.fm for books" -- a site where I can find people that have read the same books that I have?\n',
#  'LeEco Le Max2 vs OnePlus 3, which one should you buy?\n',
#  'Is there an immigration check when I leave UK as I enter UK or they take data from the airlines?\n',
#  'Should I commit suicide if I failed in my final exams?\n',
#  'What is your biggest fear in life?\n',
#  "What is Apple's corporate slogan? What does it mean?\n",
#  'Can I get a free chat plugin for my wordpress website?\n',
#  'What turns you on sexually as a woman or girl?\n',
#  'How can I repair scratches on wood floors?\n',
#  "How do we change the legal age from 18 to 25 considering brains aren't fully developed until then.?\n",
#  'Has Amazon S3 ever lost data permanently?\n',
#  'What percent of smokers develop cancer vs non smokers?\n',
#  'What is your contribution in making world a better place to live?\n',
#  'Who is the Greatest badass in history?\n',
#  'How much money is enough for a student to live in Birmingham, UK?\n',
#  'How can a street photographer get paid?\n',
#  'Have solar sails ever been tested?\n',
#  'Will the US invade California?\n',
#  'What can I do to make sure I am becoming the best version of myself?\n',
#  'What is the maximum temperature stability of carbon fiber composite and glass fiber composite?\n',
#  'After I proposed to my best friend without expectations, she now refuses to talk with me. I want her as friend. How should I convince her?\n',
#  'How much has your salary increased from your first job to today?\n',
#  'What is it like to study psychology at U Washington?\n',
#  "Is 'complacent' a negative word?\n",
#  'Is being an sensitive person a  bad thing?\n',
#  'Which is the best Indian patriotic song?\n',
#  "How can I handle having personal issues with my partner's parents? My partner refuses to acknowledge their wrong-doings.\n",
#  'What do you enjoy about sex?\n',
#  "What are the signs when a pregnant woman's water breaks?\n",
#  "Men, honest advice.. Why won't he give up pursuing me after two years?\n",
#  'How to register my mobile number online (Canara bank)?\n',
#  'How can I access a device on the same Wi-Fi network without knowing its password (hack)?\n',
#  'What is the best HUD system you have used till date?\n',
#  'What would be some extremely warm socks that can be worn with a barefoot style of running shoes?\n',
#  'What does it feel like to be at a low position in a workplace when compared to your friends who are working various positions in top notch companies?\n',
#  "When did the laws change to if you're convicted of a law your gun ownership is taken away? And how do you get your owning a firearm rights restored?\n",
#  'What was your least favorite movie of 2016?\n',
#  "Why do lot of people don't follow the principles of swami vivekananda?\n",
#  'Is the Bannerghatta campus of Christ University too far from the city?\n',
#  'What does it mean if my ex likes all of my Facebook statuses and pictures?\n',
#  "What bike will be suitable for a guy of low height (5'2'') and low weight (45 kg) in India?\n",
#  'What are some alternatives to SubtlePatterns.com?\n',
#  "How do you know if you're ready to have sex?\n",
#  'Can I use the simple past tense instead of the present perfect tense in these sentences?\n',
#  'What is the difference between information design and interaction design?\n',
#  'What does a communications manager do?\n',
#  'What strikes first time visitors as special or unusual when they arrive in Malmö, Sweden?\n',
#  'In the crossroads scene in the movie Cast Away, did Chuck end up going back to that women with the wings symbol?\n',
#  "Can my baby get a shock when he is in my hands while I'm switching on the gas stove because I felt a mild shock?\n",
#  'Which is a suitable inpatient drug and alcohol rehab center in Lyon County KY?\n',
#  'What are causes of hyperinflation?\n',
#  'What is the most asked question in an interview?\n',
#  'Will terrorism in the world ever stop?\n',
#  'How do you livestream Instagram hashtags?\n',
#  'Should the Czech Republic be renamed the "Check" Republic?\n',
#  'Is BEL an appropriate firm for doing summer training by a mechanical engineer?\n',
#  'What are the different ways of digital marketing?\n',
#  'If I delete someone from my Snapchat friend list, will he be able to see my best friends list?\n',
#  'What kind of job will a MS graduate in MIS get?\n',
#  'How popular were public executions as entertainment in the Europe of the 19th century?\n',
#  'Why are the 5 million non-Jewish victims of the Holocaust rarely mentioned?\n',
#  'Which is good part time job in Chennai?\n',
#  "Why does my friend's last seen on Whatsapp keep changing back?\n",
#  'Why some people commit suicide?\n',
#  'Which country do you think is better overall- UK or USA?\n',
#  'Is it legal to drink alcohol while in an RV?\n',
#  'We can find entropy of irreversible process by assuming that process reversible and answer will be same. Can I apply the same for adiabatic process?\n',
#  'In retrospect, did Magic Johnson need to retire from the NBA due to his having HIV?\n',
#  'How do portable air conditioners work?\n',
#  'Can you change the way a girl thinks about you?\n',
#  'What happens if you eat hair?\n',
#  'What is Elon Musk like in person?\n',
#  'What is it like to work at the Border Security Force?\n',
#  'Does testosterone increase in a man just by talking to a woman?\n',
#  'How do midlife crises end?\n',
#  'Who are some of the best audiobook readers and why?\n',
#  "A girl that I like, who shall remain nameless, has a boyfriend that she met on Kik. I'm really sad now, what should I do?\n",
#  'What universities does Trillium Therapeutics recruit new grads from? What majors are they looking for?\n',
#  "What are some of the best begging signs you've seen?\n",
#  'Is Pakistan an Islamic Nation?\n',
#  'How can I avoid any news with the word Trump?\n',
#  'How did Apple keep the design of AirPods secret?\n',
#  "What's the best technology to use that turns text into audio?\n",
#  'Are Kayak price alerts useful?\n',
#  'On Jan. 20, 2017, after Trump is sworn in, will the Obamas go where ever they plan to go first, aboard Air Force 2?\n',
#  'What is the best touchscreen alternative to a MacBook Pro in 2016?\n',
#  'How Uber makes money?\n',
#  'How do I to trace a phone call in real time with good accuracy?\n',
#  'How is the ionic equation for magnesium nitrate and sodium carbonate determined?\n',
#  'Why did it take so long for NASA to find water on Mars?\n',
#  'How has the Mormon Church been able to remain dominant in Utah, while other parts of the nation that used to be predominantly Protestant/Evangelical are now secularized?\n',
#  'How do I lose belly fat in a month without going to the gym?\n',
#  'What should I know to become a CIO?\n',
#  'What is computer?\n',
#  'How do highway signs work to reflect light back to the viewer?\n',
#  'How can I really make money online?\n',
#  'Should a person have a right to end their own life if they want to?\n',
#  'Does the Big Bang infinitely repeat itself?\n',
#  'What are promise rings? How do you wear them?\n',
#  'What should everyone need to know about the 2014 Yahoo hack?\n',
#  'What happens to an object if it reaches the speed of light?\n',
#  'What is another name for a nerve cell?\n',
#  'Why did zhao gao execute so many sons and daughters of the first emperor?\n',
#  'Which are the three more realistic ways to become a multi millionaire before 30?\n',
#  'How do I create an interactive website without coding and programming (skills)?\n',
#  'What are the rights of a prisoner?\n',
#  'Do you have a high school diploma, GED or international equivalent?\n',
#  "What are the Monkey King's powers (Sun Wukong)?\n",
#  'Why do they bury people with the gravestone at their feet instead of at their head?\n',
#  'How did your parents react when they came to know that you lost your virginity?\n',
#  'How is the Luxury/Imported car segment expected to change with the arrival of GST?\n',
#  "What percentage of Vietnam's culture from food, traditions, etc would you say is derived or influenced by China?\n",
#  'When should I go deep sea fishing in UAE?\n',
#  'What are some reasons that a guy would wear thong underwear instead of boxers or briefs?\n',
#  'What are some of the best online tutorials on front end development?\n',
#  'What makes you feel loved?\n',
#  'What could Mexico do to attract high tech American businesses that no longer wish to do business in the Untied States under a Trump presidency?\n',
#  'Could a psychopath become a good CEO?\n',
#  'How do you know what are the healthiest diet sodas?\n',
#  'What is T.S diagram?\n',
#  'Why do so many Western people have so much venom toward China?\n',
#  'What are good topics for an architecture graduation thesis?\n',
#  'Can a microbes/germ or fungi, or simple animals e.g. Caenorhabditis elegans get cancer?\n',
#  'What are the hottest startups in Ireland?\n',
#  'What does it take to have a good day?\n',
#  "When light bounces off an electron in the Compton effect and loses energy (giving it to the electron) wouldn't that slow it down?\n",
#  'What is a FRCP medical degree?\n',
#  'What are the best petting zoos within a few hours of the San Francisco Bay Area?\n',
#  'Is it possible to rely only on Nik Color Efex Pro for photo editing?\n',
#  'Top Writers Program?\n',
#  'Did Christianity transform Rome or did Rome change Christianity?\n',
#  'What is supply chain management of Berger and Nerolac Paints?\n',
#  'What shape is the event horizon of the universe?\n',
#  'I have a salary of 15 lpa with 3 years experience, but have only B.Tech degree, Do I have to pursue higher studies to grow in career?\n',
#  'What types of questions are asked in the interview of IISc Bangalore for students who want to pursue an integrated PhD in chemistry?\n',
#  'Do engineering classes depend on physics and calculus?\n',
#  'How can you use different types of noises (not including music) to change brain waves? And in what way?\n',
#  "Which is better for one's life, knowing more people or gaining more knowledge?\n",
#  'Why do women want to get plastic surgery to look like a celebrity?\n',
#  'Which is better, chemical at BITS Goa or chemical at BITS Hyderabad?\n',
#  'Is there really need of ₹2000 notes in India?\n',
#  'Should I quit engineering?\n',
#  'Is journalism a good career nowadays?\n',
#  'Who makes more money, a portfolio manager from a hedge fund or one from a large asset manager, like Blackrock or Vanguard?\n',
#  'What are "unit economics"?\n',
#  'Origin of udeniya (Brahmins)?\n',
#  "Is it weird that I'm attracted to men who crossdress?\n",
#  'Is there a way on Facebook to unfriend someone without them noticing?\n',
#  'Where can I get a database of Canadian family offices?\n',
#  ...]

# %% [markdown]
# __Tokenization:__ a typical first step for an NLP task is to split raw data into words.
# The text we're working with is in raw format: with all the punctuation and emojis attached to some words, so a simple str.split won't do.
#
# Let's use __`nltk`__ - a library that handles many NLP tasks like tokenization, stemming, or part-of-speech tagging.

# %%
from nltk.tokenize import WordPunctTokenizer
tokenizer = WordPunctTokenizer()

print(tokenizer.tokenize(data[50]))
# Out:
# ['What', 'TV', 'shows', 'or', 'books', 'help', 'you', 'read', 'people', "'", 's', 'body', 'language', '?']

# %%
# TASK: lowercase everything and extract tokens with tokenizer.
# data_tok should be a list of lists of tokens for each line in data.

data_tok = [[tok.lower() for tok in tokenizer.tokenize(text)] for text in data]  # YOUR CODE
data_tok[::1000]
# Out:
# [['can',
#   'i',
#   'get',
#   'back',
#   'with',
#   'my',
#   'ex',
#   'even',
#   'though',
#   'she',
#   'is',
#   'pregnant',
#   'with',
#   'another',
#   'guy',
#   "'",
#   's',
#   'baby',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'reason',
#   'of',
#   'british',
#   'occupation',
#   'in',
#   'india',
#   '?'],
#  ['what',
#   'are',
#   'five',
#   'problems',
#   'every',
#   'programmer',
#   'should',
#   'be',
#   'able',
#   'to',
#   'answer',
#   '?'],
#  ['what', 'languages', 'are', 'you', 'fluent', 'in', '?'],
#  ['in',
#   'what',
#   'way',
#   'i',
#   'should',
#   'arrange',
#   'two',
#   'convex',
#   'lenses',
#   'to',
#   'get',
#   'highest',
#   'magnification',
#   '?',
#   'also',
#   'tell',
#   ',',
#   'what',
#   'should',
#   'be',
#   'their',
#   'focal',
#   'lengths',
#   '?'],
#  ['using',
#   'gcm',
#   'how',
#   'does',
#   'apps',
#   'like',
#   'facebook',
#   ',',
#   'quora',
#   ',',
#   'etc',
#   'send',
#   'notifications',
#   'to',
#   'a',
#   'single',
#   'user',
#   '/',
#   'device',
#   'out',
#   'of',
#   'so',
#   'many',
#   'in',
#   'the',
#   'database',
#   '?',
#   'how',
#   'exactly',
#   'is',
#   'the',
#   'server',
#   'side',
#   'setup',
#   'to',
#   'filter',
#   'users',
#   'or',
#   'devices',
#   'based',
#   'on',
#   'some',
#   'necessary',
#   'fields',
#   '?'],
#  ['will', 'neet', '2017', 'be', 'taken', 'in', 'two', 'phases', '?'],
#  ['how',
#   'do',
#   'i',
#   'know',
#   'what',
#   'martial',
#   'art',
#   'is',
#   'right',
#   'for',
#   'me',
#   '?'],
#  ['if',
#   'the',
#   'invasion',
#   'of',
#   'normandy',
#   'failed',
#   'would',
#   'hitler',
#   'have',
#   'won',
#   'the',
#   'war',
#   '?'],
#  ['how', 'are', 'bits', 'and', 'bytes', 'related', '?'],
#  ['why',
#   'don',
#   "'",
#   't',
#   'gods',
#   'have',
#   'any',
#   'last',
#   'names',
#   '(',
#   'surnames',
#   ')',
#   'like',
#   'we',
#   'do',
#   'have',
#   '?'],
#  ['who', 'loves', 'greek', 'mythology', '?'],
#  ['are', 'moths', 'dangerous', 'to', 'humans', '?'],
#  ['how',
#   'do',
#   'i',
#   'stop',
#   'my',
#   'dog',
#   'from',
#   'crying',
#   'for',
#   'no',
#   'reason',
#   '?'],
#  ['why', 'does', 'my', 'urine', 'smells', 'like', 'garlic', '?'],
#  ['what', 'was', 'life', 'in', 'america', 'like', 'in', 'the', '1600s', '?'],
#  ['when',
#   'a',
#   'man',
#   'says',
#   'he',
#   'doesn',
#   "'",
#   't',
#   'want',
#   'a',
#   'relationship',
#   'right',
#   'now',
#   ',',
#   'is',
#   'that',
#   'the',
#   'truth',
#   'or',
#   '"',
#   'he',
#   "'",
#   's',
#   'just',
#   'not',
#   'that',
#   'into',
#   'you',
#   '"?'],
#  ['is', 'denaturation', 'of', 'proteins', 'desirable', '?'],
#  ['will', 'csc', 'and', 'hp', 'benefit', 'from', 'their', 'merger', '?'],
#  ['what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'a',
#   'comet',
#   'and',
#   'an',
#   'asteroid',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'convince',
#   'my',
#   'girlfriend',
#   'to',
#   'lose',
#   'weight',
#   '?'],
#  ['if',
#   'my',
#   'boss',
#   'owes',
#   'me',
#   'money',
#   'and',
#   'won',
#   "'",
#   't',
#   'pay',
#   'me',
#   'what',
#   'can',
#   'i',
#   'do',
#   'about',
#   'it',
#   '?'],
#  ['why', 'did', 'ronaldo', 'win', 'ballon', 'd', "'", 'or', '?'],
#  ['what', 'makes', 'you', 'a', 'good', 'role', 'model', '?'],
#  ['should',
#   'i',
#   'send',
#   'official',
#   'ap',
#   'score',
#   'reports',
#   'to',
#   'colleges',
#   'when',
#   'applying',
#   ',',
#   'or',
#   'only',
#   'after',
#   'getting',
#   'admitted',
#   '?'],
#  ['i',
#   'am',
#   'in',
#   'need',
#   'of',
#   'a',
#   'laptop',
#   'and',
#   'after',
#   'researching',
#   'it',
#   'i',
#   'really',
#   'want',
#   'to',
#   'go',
#   'with',
#   'a',
#   'macbook',
#   'pro',
#   '.',
#   'should',
#   'i',
#   'buy',
#   'it',
#   'now',
#   'or',
#   'wait',
#   'for',
#   'a',
#   'new',
#   'release',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'way',
#   'to',
#   'get',
#   'traffic',
#   'to',
#   'a',
#   'genealogy',
#   'website',
#   '?'],
#  ['my',
#   'wife',
#   'and',
#   'i',
#   'regularly',
#   'reuse',
#   'styrofoam',
#   'cups',
#   'after',
#   'washing',
#   'in',
#   'the',
#   'dishwasher',
#   '.',
#   'friends',
#   'suggest',
#   'that',
#   'we',
#   'are',
#   'creating',
#   'a',
#   'health',
#   'hazard',
#   'for',
#   'ourselves',
#   '.',
#   'i',
#   'understrand',
#   'styrofoam',
#   'is',
#   'considered',
#   'safe',
#   'but',
#   'what',
#   'about',
#   'our',
#   'reuse',
#   'over',
#   'and',
#   'over',
#   '?'],
#  ['what',
#   'should',
#   'i',
#   'do',
#   'about',
#   'not',
#   'getting',
#   'any',
#   'answers',
#   'of',
#   'my',
#   'questions',
#   'on',
#   'quora',
#   '?'],
#  ['did',
#   'doug',
#   'kill',
#   'rachel',
#   'in',
#   'episode',
#   '39',
#   '(',
#   's3e13',
#   ')',
#   'of',
#   'house',
#   'of',
#   'cards',
#   'and',
#   'if',
#   'so',
#   ',',
#   'why',
#   'did',
#   'he',
#   'do',
#   'it',
#   '?'],
#  ['how', 'is', 'an', 'aquifer', 'located', '?'],
#  ['why',
#   'do',
#   'people',
#   'say',
#   '"',
#   'it',
#   "'",
#   's',
#   'hard',
#   'to',
#   'get',
#   'into',
#   'university',
#   'of',
#   'toronto',
#   '"',
#   'is',
#   'it',
#   'more',
#   'difficult',
#   'than',
#   'most',
#   'selective',
#   'universities',
#   'in',
#   'the',
#   'us',
#   ',',
#   'like',
#   'under',
#   '50',
#   '%',
#   'rate',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'fill',
#   'my',
#   'big',
#   'stomach',
#   'with',
#   'zero',
#   'calories',
#   'or',
#   'low',
#   'calories',
#   '?'],
#  ['which',
#   'is',
#   'the',
#   'best',
#   'camera',
#   'smartphone',
#   'under',
#   '15k',
#   'in',
#   'india',
#   '?'],
#  ['what', 'font', 'is', 'used', 'in', 'this', 'picture', '?'],
#  ['what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'a',
#   'simulator',
#   'and',
#   'an',
#   'emulator',
#   '?'],
#  ['what', 'stores', 'sell', 'dreamcatchers', '?'],
#  ['what',
#   'are',
#   'some',
#   'good',
#   'free',
#   'ebooks',
#   'or',
#   'pdf',
#   'files',
#   'on',
#   'recording',
#   'engineering',
#   'or',
#   'audio',
#   'engineering',
#   '?'],
#  ['is',
#   'there',
#   'any',
#   'particle',
#   'that',
#   'interacts',
#   'with',
#   'matter',
#   'but',
#   'able',
#   'to',
#   'go',
#   'through',
#   'an',
#   'entire',
#   'planet',
#   '?',
#   'like',
#   'a',
#   'photon',
#   'or',
#   'a',
#   'neutrino',
#   '?'],
#  ['which',
#   'is',
#   'the',
#   'best',
#   'breed',
#   'of',
#   'cat',
#   'for',
#   'a',
#   'working',
#   'couple',
#   '?'],
#  ['who',
#   'should',
#   'mulims',
#   'vote',
#   'for',
#   'trump',
#   'who',
#   'wants',
#   'to',
#   'ban',
#   'them',
#   'or',
#   'hillary',
#   'who',
#   'wants',
#   'to',
#   'bomb',
#   'them',
#   '?'],
#  ['what', 'does', 'psomí', 'mean', '?'],
#  ['what', 'is', 'mechanical', 'engineer', '?'],
#  ['in', 'mythologies', ',', 'what', 'do', 'mermaids', 'usually', 'eat', '?'],
#  ['how',
#   'can',
#   'we',
#   'find',
#   'professors',
#   ',',
#   'phd',
#   '&',
#   'masters',
#   'students',
#   'from',
#   'universities',
#   'of',
#   'ukraine',
#   'who',
#   'would',
#   'like',
#   'to',
#   'share',
#   'their',
#   'knowledge',
#   'for',
#   'free',
#   'to',
#   'record',
#   'moocs',
#   '?'],
#  ['what', 'is', 'the', 'best', 'way', 'to', 'crack', 'gate', '2018', '?'],
#  ['how',
#   'would',
#   'western',
#   'history',
#   'be',
#   'different',
#   'if',
#   'carthage',
#   'had',
#   'defeated',
#   'the',
#   'roman',
#   'republic',
#   'in',
#   'the',
#   'punic',
#   'wars',
#   '?'],
#  ['how',
#   'does',
#   'a',
#   'face',
#   'become',
#   'more',
#   'attractive',
#   'during',
#   'weight',
#   'loss',
#   '?'],
#  ['what', 'mistakes', 'have', 'you', 'made', 'in', 'life', '?'],
#  ['what', 'are', 'some', 'freelancing', 'tips', '?'],
#  ['which',
#   'college',
#   'i',
#   'can',
#   'get',
#   'with',
#   '1577',
#   'rank',
#   'in',
#   'neet',
#   '2016',
#   '?'],
#  ['how',
#   'is',
#   'the',
#   'iit',
#   'food',
#   'menu',
#   'in',
#   'the',
#   'hostel',
#   'mess',
#   '?'],
#  ['how', 'good', 'at', 'math', 'is', 'tony', 'stark', '?'],
#  ['is',
#   'it',
#   'a',
#   'guarantee',
#   'that',
#   'you',
#   'will',
#   'lose',
#   'some',
#   'senses',
#   'because',
#   'of',
#   'nerve',
#   'damage',
#   'after',
#   'orthognathic',
#   'surgery',
#   '?'],
#  ['what', 'was', 'your', 'first', 'date', 'like', '?'],
#  ['what', 'do', 'you', 'think', 'is', 'meant', 'by', 'time', 'travel', '?'],
#  ['what',
#   'is',
#   'the',
#   'scope',
#   'of',
#   'cse',
#   'with',
#   'specialization',
#   'in',
#   'bioinformatics',
#   'in',
#   'india',
#   '?'],
#  ['why', 'is', 'coming', 'first', 'a', 'big', 'deal', '?'],
#  ['how',
#   'often',
#   'should',
#   'i',
#   'text',
#   'my',
#   'long',
#   'distance',
#   'crush',
#   '(',
#   'every',
#   'day',
#   ',',
#   'two',
#   'days',
#   ',',
#   'once',
#   'a',
#   'week',
#   ')?'],
#  ['how',
#   'many',
#   'marks',
#   'in',
#   'twelfth',
#   'bihar',
#   'board',
#   'is',
#   'required',
#   'for',
#   'the',
#   'jee',
#   'advance',
#   'cut',
#   'off',
#   '?'],
#  ['how', 'do', 'i', 'know', 'if', 'my', 'girlfriend', 'need', 'sex', '?'],
#  ['what', 'is', 'dark', 'web', '?', 'what', 'happens', 'there', '?'],
#  ['did', 'italy', 'get', 'pasta', 'from', 'china', '?'],
#  ['what',
#   'are',
#   'some',
#   'of',
#   'the',
#   'best',
#   'smelling',
#   'deodorants',
#   '-',
#   'for',
#   'men',
#   '?'],
#  ['will',
#   'sagittarius',
#   'a',
#   '*',
#   'eventually',
#   'suck',
#   'in',
#   'everything',
#   'in',
#   'our',
#   'galaxy',
#   'over',
#   'billions',
#   'and',
#   'billions',
#   'of',
#   'years',
#   '?'],
#  ['can',
#   'upgrade',
#   'dell',
#   'streak',
#   'pro',
#   'd43',
#   'with',
#   'baidu',
#   'yi',
#   'to',
#   'android',
#   '4',
#   '?'],
#  ['is',
#   'there',
#   'any',
#   'milk',
#   'brand',
#   'in',
#   'india',
#   'that',
#   'provides',
#   '100',
#   '%',
#   'pure',
#   'milk',
#   'without',
#   'any',
#   'human',
#   'contact',
#   '?'],
#  ['ancoring', 'script', 'for', 'alumini', 'meet', '?'],
#  ['what', 'is', 'jio', '?'],
#  ['what',
#   'do',
#   'native',
#   'americans',
#   'want',
#   'to',
#   'be',
#   'called',
#   'by',
#   'others',
#   '?'],
#  ['can', 'dogs', 'eat', 'cat', 'food', '?'],
#  ['how',
#   'can',
#   'i',
#   'treat',
#   'this',
#   'khyphosis',
#   '?',
#   'will',
#   'it',
#   'be',
#   'treated',
#   'and',
#   'spine',
#   'becomes',
#   'ideal',
#   'again',
#   '?'],
#  ['what', 'is', 'it', 'like', 'to', 'use', 'butt', 'plugs', '?'],
#  ['what', 'is', 'the', 'largest', 'lake', 'in', 'india', '?'],
#  ['what', 'physiological', 'tricks', 'are', 'useful', 'to', 'know', '?'],
#  ['how', 'can', 'you', 'repair', 'tooth', 'enamel', '?'],
#  ['i',
#   'am',
#   'pursuing',
#   'economics',
#   'hons',
#   'from',
#   'delhi',
#   'university',
#   '.',
#   'i',
#   'am',
#   'confused',
#   'about',
#   'my',
#   'pg',
#   '.',
#   'what',
#   'are',
#   'the',
#   'various',
#   'options',
#   'present',
#   'for',
#   'a',
#   'pg',
#   'after',
#   'eco',
#   'hons',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'good',
#   'examples',
#   'of',
#   'web',
#   'based',
#   'project',
#   'management',
#   'software',
#   '?'],
#  ['why', 'do', 'we', 'feel', 'sorry', 'for', 'ourselves', '?'],
#  ['why',
#   'doesn',
#   "'",
#   't',
#   'the',
#   'government',
#   'of',
#   'india',
#   'remove',
#   'the',
#   'system',
#   'of',
#   'reservations',
#   '?'],
#  ['will',
#   'president',
#   'donald',
#   'trump',
#   'attempt',
#   'to',
#   'arrest',
#   'hillary',
#   'clinton',
#   'over',
#   'her',
#   'e',
#   '-',
#   'mail',
#   'scandal',
#   '?'],
#  ['show',
#   'that',
#   'the',
#   'set',
#   'g',
#   '=',
#   '{',
#   '1',
#   ',',
#   '2',
#   ',',
#   '3',
#   ',…',
#   'p',
#   '-',
#   '1',
#   '..}',
#   'of',
#   'non',
#   'zero',
#   'integer',
#   'module',
#   'p',
#   '.',
#   'p',
#   'is',
#   'prime',
#   'under',
#   'multiplication',
#   'module',
#   'p',
#   'is',
#   'group',
#   '?'],
#  ['how',
#   'is',
#   'everyone',
#   'earning',
#   'millions',
#   'from',
#   'home',
#   'by',
#   'just',
#   'using',
#   'uber',
#   'app',
#   'in',
#   'mobile',
#   '?'],
#  ['what', 'is', 'document', 'required', 'for', 'loan', '?'],
#  ['what', 'is', 'the', 'scope', 'of', 'laser', 'in', 'the', 'future', '?'],
#  ['how', 'do', 'i', 'get', 'over', 'a', 'major', 'failure', '?'],
#  ['as', 'a', 'christian', 'what', 'is', 'your', 'view', 'on', 'god', '?'],
#  ['what', 'should', 'one', 'take', 'as', 'a', 'souvenir', 'from', 'goa', '?'],
#  ['there',
#   'are',
#   'ego',
#   'problems',
#   'in',
#   'relationships',
#   'these',
#   'days',
#   '.',
#   'what',
#   'is',
#   'the',
#   'worse',
#   'incident',
#   'of',
#   'break',
#   'up',
#   'due',
#   'to',
#   'ego',
#   'problem',
#   '?'],
#  ['how', 'can', 'i', 'loose', '5', 'kgs', 'weight', 'in', '10', 'days', '?'],
#  ['what',
#   'is',
#   'the',
#   'importance',
#   'of',
#   'mitosis',
#   'and',
#   'meiosis',
#   'and',
#   'what',
#   'are',
#   'their',
#   'differences',
#   '?'],
#  ['is', 'russia', 'siding', 'with', 'pakistan', '?'],
#  ['what', 'is', 'the', 'most', 'peaceful', 'time', 'in', 'history', '?'],
#  ['does', 'life', 'goes', 'the', 'way', 'we', 'think', '?'],
#  ['how',
#   'do',
#   'big',
#   'data',
#   'databases',
#   'handle',
#   'the',
#   'problem',
#   'of',
#   'primary',
#   'key',
#   'values',
#   'running',
#   'out',
#   'given',
#   'that',
#   'the',
#   'key',
#   'is',
#   'not',
#   'unlimited',
#   'size',
#   '?'],
#  ['how', 'many', 'people', 'applied', 'to', 'isb', 'ylp', 'in', '2013', '?'],
#  ['how',
#   'can',
#   'i',
#   'make',
#   'default',
#   'storage',
#   'to',
#   'memory',
#   'card',
#   'in',
#   'lenovo',
#   'k3',
#   'note',
#   '?'],
#  ['my',
#   'friend',
#   'went',
#   'abroad',
#   'for',
#   'a',
#   'few',
#   'days',
#   'and',
#   'is',
#   'trying',
#   'to',
#   'make',
#   'me',
#   'jealous',
#   '.',
#   'how',
#   'do',
#   'i',
#   'react',
#   '?'],
#  ['how',
#   'did',
#   'the',
#   'olmec',
#   'people',
#   'transport',
#   'the',
#   'boulders',
#   'used',
#   'for',
#   'building',
#   'the',
#   'olmec',
#   'heads',
#   'considering',
#   'the',
#   'fact',
#   'that',
#   'they',
#   'never',
#   'invented',
#   'the',
#   'wheel',
#   '?',
#   'also',
#   ',',
#   'how',
#   'did',
#   'they',
#   'carve',
#   'the',
#   'stones',
#   'to',
#   'make',
#   'these',
#   'heads',
#   '?'],
#  ['how', 'does', 'the', 'dos', 'attack', 'can', 'be', 'done', '?'],
#  ['which',
#   'is',
#   'the',
#   'best',
#   'cleaning',
#   'service',
#   'company',
#   'in',
#   'australia',
#   '?'],
#  ['why',
#   'don',
#   "'",
#   't',
#   'we',
#   'see',
#   'once',
#   'wild',
#   ',',
#   'but',
#   'now',
#   'domesticated',
#   'animals',
#   'in',
#   'their',
#   'natural',
#   'habitats',
#   'anymore',
#   '?'],
#  ['what', 'is', 'the', 'past', 'form', 'of', 'open', '?'],
#  ['when',
#   'neutral',
#   'and',
#   'ground',
#   'wires',
#   'get',
#   'interchanged',
#   ',',
#   'there',
#   'is',
#   'flickering',
#   'in',
#   'the',
#   'tube',
#   'lights',
#   '.',
#   'why',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'send',
#   'a',
#   'text',
#   'if',
#   'someone',
#   'has',
#   'blocked',
#   'me',
#   'on',
#   'snapchat',
#   '?'],
#  ['t',
#   '-',
#   'sql',
#   'is',
#   'for',
#   'an',
#   'ms',
#   'sql',
#   'server',
#   '.',
#   'on',
#   'the',
#   'same',
#   'lines',
#   ',',
#   'which',
#   'language',
#   'is',
#   'used',
#   'for',
#   'mysql',
#   'rdbms',
#   '?'],
#  ['should',
#   'i',
#   'purchase',
#   'a',
#   'honda',
#   'amaze',
#   'or',
#   'toyota',
#   'etios',
#   '?'],
#  ['could',
#   'a',
#   'person',
#   'feel',
#   'absolutely',
#   'nothing',
#   'if',
#   'we',
#   'look',
#   'each',
#   'other',
#   'in',
#   'the',
#   'eyes',
#   'for',
#   'a',
#   'longer',
#   'duration',
#   '?'],
#  ['can',
#   'i',
#   'upgrade',
#   'my',
#   'laptop',
#   'with',
#   '7200rpm',
#   'hdd',
#   '?',
#   'my',
#   'laptop',
#   'model',
#   'is',
#   'hp',
#   'starwars',
#   'edition',
#   '2016',
#   'with',
#   'i5',
#   '–',
#   '6200u'],
#  ['what', 'is', 'dynamic', 'view', '?'],
#  ['how',
#   'does',
#   'the',
#   'climate',
#   'in',
#   'europe',
#   'today',
#   'compare',
#   'to',
#   'one',
#   'thousand',
#   'years',
#   'ago',
#   '?'],
#  ['does',
#   'putin',
#   'actually',
#   'care',
#   'at',
#   'all',
#   'about',
#   'the',
#   'future',
#   'of',
#   'russia',
#   '?'],
#  ['what',
#   'makes',
#   'harvard',
#   'one',
#   'of',
#   'the',
#   'best',
#   'universities',
#   'in',
#   'the',
#   'world',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'relationship',
#   'between',
#   'voltage',
#   'and',
#   'rpm',
#   'in',
#   'an',
#   'ac',
#   'motor',
#   '?'],
#  ['do', 'people', 'in', 'china', 'eat', 'walnuts', '?'],
#  ['what', 'are', 'the', 'limitation', 'of', 'classical', 'conditioning', '?'],
#  ['why', 'is', 'skydiving', 'expensive', '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'way',
#   'to',
#   'remove',
#   'blackhead',
#   'scars',
#   '?'],
#  ['i',
#   'have',
#   'a',
#   'great',
#   'idea',
#   'for',
#   'a',
#   'women',
#   "'",
#   's',
#   'clothing',
#   'company',
#   '.',
#   'i',
#   'have',
#   'the',
#   'general',
#   'business',
#   'plan',
#   'and',
#   'concept',
#   'down',
#   ',',
#   'but',
#   'i',
#   'have',
#   'zero',
#   'experience',
#   'with',
#   'creating',
#   'clothing',
#   '.',
#   'how',
#   'would',
#   'i',
#   'go',
#   'about',
#   'finding',
#   'the',
#   'right',
#   'avenues',
#   'and',
#   'people',
#   'to',
#   'get',
#   'started',
#   '?'],
#  ['what',
#   'is',
#   'a',
#   'good',
#   'stock',
#   'screener',
#   'for',
#   'korean',
#   'stocks',
#   '?'],
#  ['what', 'are', 'the', 'ways', 'to', 'find', 'a', 'stolen', 'laptop', '?'],
#  ['is', '128', 'a', 'good', 'iq', 'for', 'a', 'nine', 'year', 'old', '?'],
#  ['why',
#   'do',
#   'bus',
#   'drivers',
#   'wait',
#   'at',
#   'stops',
#   'even',
#   'though',
#   'no',
#   'else',
#   'is',
#   'getting',
#   'on',
#   'or',
#   'off',
#   '?'],
#  ['how', 'can', 'i', 'get', 'bigger', 'shoulders', '?'],
#  ['from',
#   'which',
#   'website',
#   'i',
#   'can',
#   'download',
#   'latest',
#   'and',
#   'all',
#   'english',
#   'songs',
#   '?'],
#  ['which',
#   'is',
#   'a',
#   'better',
#   'phone',
#   ':',
#   'an',
#   'honor',
#   '4x',
#   'or',
#   'a',
#   'lenovo',
#   'k3',
#   'note',
#   '?'],
#  ['should', 'a', '15', 'year', 'old', 'boy', 'have', 'a', 'job', '?'],
#  ['how',
#   'reliable',
#   'are',
#   'the',
#   'results',
#   'of',
#   'versant',
#   'language',
#   'test',
#   '?'],
#  ['is', 'petroleum', 'engineering', 'still', 'a', 'good', 'major', '?'],
#  ['can',
#   'we',
#   'assemble',
#   'and',
#   'install',
#   'a',
#   'mp3',
#   'player',
#   'or',
#   'ipod',
#   'by',
#   'ourselves',
#   '?'],
#  ['is',
#   'it',
#   'better',
#   'to',
#   'do',
#   'a',
#   'ms',
#   'in',
#   'us',
#   'or',
#   'a',
#   'ms',
#   'in',
#   'germany',
#   '?'],
#  ['korean', 'drama', 'viki', '?'],
#  ['where', 'can', 'you', 'trade', 'commodities', 'online', '?'],
#  ['can', 'we', 'use', 'hair', 'gel', 'for', 'beard', '?'],
#  ['are',
#   'sikhs',
#   'more',
#   'religious',
#   'and',
#   'more',
#   'generous',
#   'than',
#   'christians',
#   '?'],
#  ['i',
#   "'",
#   'm',
#   'traveling',
#   'to',
#   'london',
#   'solo',
#   'and',
#   'want',
#   'to',
#   'meet',
#   'cool',
#   'people',
#   '.',
#   'should',
#   'i',
#   'stay',
#   'at',
#   'a',
#   'hostel',
#   'or',
#   'book',
#   'something',
#   'on',
#   'airbnb',
#   '?'],
#  ['what', 'is', 'kai', 'the', 'robot', '?'],
#  ['what',
#   'is',
#   'netserver',
#   '.',
#   'app',
#   'and',
#   'should',
#   'i',
#   'allow',
#   'it',
#   'to',
#   'accept',
#   'incoming',
#   'network',
#   'connections',
#   '?'],
#  ['what', 'is', 'diaspora', '?'],
#  ['is',
#   'metasearch',
#   'in',
#   'travel',
#   'a',
#   'substantial',
#   'business',
#   'model',
#   '?'],
#  ['who', 'were', 'the', 'famous', 'british', 'restaurants', 'owner', '?'],
#  ['is',
#   'college',
#   'football',
#   'played',
#   'under',
#   'canadian',
#   'football',
#   'rules',
#   'popular',
#   'in',
#   'canada',
#   '?'],
#  ['the', 'earth', 'is', 'not', 'exactly', 'spherical', '.', 'why', '?'],
#  ['how',
#   'can',
#   'i',
#   'find',
#   'hidden',
#   'wasp',
#   'nests',
#   'and',
#   'eradicate',
#   'them',
#   '?'],
#  ['is', 'food', 'addictive', '?'],
#  ['how',
#   'serious',
#   'are',
#   'the',
#   'effects',
#   'of',
#   'human',
#   'population',
#   'on',
#   'climate',
#   'change',
#   'and',
#   'natural',
#   'resources',
#   '?'],
#  ['why', 'do', 'we', 'forget', 'dreams', 'so', 'quickly', '?'],
#  ['how', 'can', 'i', 'remove', 'spiders', 'from', 'my', 'house', '?'],
#  ['what',
#   'do',
#   'you',
#   'think',
#   'of',
#   'the',
#   'name',
#   "'",
#   'zephyr',
#   "'",
#   'for',
#   'a',
#   'girl',
#   '?'],
#  ['how', 'is', 'apple', 'innovative', '?'],
#  ['are',
#   'there',
#   'modern',
#   '-',
#   'day',
#   'hippies',
#   '?',
#   'where',
#   'are',
#   'they',
#   'and',
#   'how',
#   'do',
#   'they',
#   'live',
#   '?'],
#  ['why', 'should', 'pregnant', 'women', 'eat', 'pomegranate', '?'],
#  ['what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'interpretation',
#   'and',
#   'translation',
#   '?'],
#  ['subscribe', 'data', 'protection', 'through', 'virtualization', '?'],
#  ['what',
#   'is',
#   'any',
#   'extra',
#   'charge',
#   'if',
#   'i',
#   'deposit',
#   'cash',
#   'through',
#   'an',
#   'atm',
#   'branch',
#   'of',
#   'an',
#   'sbi',
#   'or',
#   'any',
#   'other',
#   'bank',
#   '?'],
#  ['how',
#   'does',
#   'computer',
#   'science',
#   'and',
#   'electrical',
#   'engineering',
#   'programmes',
#   'at',
#   'iit',
#   'delhi',
#   'compare',
#   'in',
#   'terms',
#   'of',
#   'placements',
#   '?',
#   'answers',
#   'with',
#   'numbers',
#   '(',
#   'and',
#   'not',
#   'just',
#   'cse',
#   '>',
#   'ee',
#   ')',
#   'are',
#   'expected',
#   '.'],
#  ['what',
#   'is',
#   'it',
#   'like',
#   'to',
#   'be',
#   'beautiful',
#   '?',
#   'not',
#   'just',
#   'pretty',
#   'or',
#   'hot',
#   ',',
#   'but',
#   'the',
#   'kind',
#   'of',
#   'almost',
#   'objective',
#   'beauty',
#   'that',
#   'people',
#   'are',
#   'sometimes',
#   'intimidated',
#   'by',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'essential',
#   'skills',
#   'for',
#   'a',
#   'electronic',
#   'engineer',
#   '?'],
#  ['why', 'does', 'my', 'stomach', 'feel', 'cold', 'inside', '?'],
#  ['what',
#   'do',
#   'the',
#   'members',
#   'of',
#   'the',
#   'legislative',
#   'assembly',
#   'do',
#   '?'],
#  ['do',
#   'employees',
#   'at',
#   'international',
#   'speedway',
#   'have',
#   'a',
#   'good',
#   'work',
#   '-',
#   'life',
#   'balance',
#   '?',
#   'does',
#   'this',
#   'differ',
#   'across',
#   'positions',
#   'and',
#   'departments',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'tips',
#   'on',
#   'making',
#   'it',
#   'through',
#   'the',
#   'job',
#   'interview',
#   'process',
#   'at',
#   'artisan',
#   'partners',
#   '?'],
#  ['what', 'are', 'the', 'security', 'vulnerabilities', 'in', 'http', '?'],
#  ['what', "'", 's', 'it', 'like', 'meeting', 'azim', 'premji', '?'],
#  ['why', 'is', 'narendra', 'modi', 'not', 'fluent', 'in', 'english', '?'],
#  ['can', 'stress', 'cause', 'rectal', 'bleeding', '?'],
#  ['what',
#   'is',
#   'the',
#   'iupac',
#   'names',
#   'of',
#   'the',
#   'following',
#   'compounds',
#   '?'],
#  ['if',
#   'you',
#   'are',
#   'single',
#   ',',
#   'after',
#   'what',
#   'age',
#   'is',
#   'it',
#   'better',
#   'to',
#   'be',
#   'single',
#   'for',
#   'the',
#   'rest',
#   'of',
#   'your',
#   'life',
#   '?'],
#  ['what',
#   'percentage',
#   'of',
#   'international',
#   'students',
#   'pay',
#   'for',
#   'their',
#   'phd',
#   'in',
#   'australia',
#   '?'],
#  ['how', 'can', 'you', 'change', 'the', 'imei', 'of', 'an', 'iphone', '?'],
#  ['is', 'the', 'universe', 'expanding', 'day', 'by', 'day', '?'],
#  ['how',
#   'can',
#   'one',
#   'hide',
#   'his',
#   '/',
#   'her',
#   'private',
#   'apps',
#   'in',
#   'android',
#   'phone',
#   '?'],
#  ['is', 'ruby', 'on', 'rails', 'dead', '?'],
#  ['are', 'wolverine', '1000', 'mile', 'boots', 'durable', '?'],
#  ['which', 'posts', 'are', 'in', 'mpsc', '?'],
#  ['why',
#   'do',
#   'we',
#   'see',
#   'colors',
#   'when',
#   'we',
#   'close',
#   'our',
#   'eyes',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'prove',
#   'the',
#   'independence',
#   'of',
#   'a',
#   'product',
#   'of',
#   'random',
#   'variables',
#   '?'],
#  ['what', 'is', 'your', 'review', 'of', 'mysql', 'performance', '?'],
#  ['what',
#   'is',
#   'the',
#   'most',
#   'nutritionally',
#   '-',
#   'dense',
#   'food',
#   ',',
#   'with',
#   'the',
#   'least',
#   'calories',
#   '?'],
#  ['why', 'do', 'people', 'hate', 'common', 'core', 'standards', '?'],
#  ['formula',
#   'one',
#   '-',
#   'why',
#   'did',
#   'ayrton',
#   'senna',
#   "'",
#   's',
#   'head',
#   'move',
#   'after',
#   'his',
#   'crash',
#   '?',
#   'how',
#   'did',
#   'his',
#   'injuries',
#   'kill',
#   'him',
#   'and',
#   'how',
#   'quick',
#   'was',
#   'his',
#   'death',
#   '?'],
#  ['i',
#   "'",
#   'm',
#   '20',
#   'years',
#   'old',
#   'and',
#   'i',
#   'have',
#   '$',
#   '15',
#   ',',
#   '000',
#   'from',
#   'working',
#   'that',
#   'i',
#   'want',
#   'to',
#   'invest',
#   '.',
#   'what',
#   'should',
#   'i',
#   'do',
#   '?'],
#  ['what', 'are', 'some', 'examples', 'of', 'imprinting', 'in', 'animals', '?'],
#  ['what',
#   'are',
#   'the',
#   'pros',
#   'and',
#   'cons',
#   'of',
#   'fishing',
#   'with',
#   'tube',
#   'flies',
#   '?'],
#  ['where', 'can', 'i', 'find', 'designer', 'fashion', 'jewellery', '?'],
#  ['how',
#   'many',
#   'times',
#   'have',
#   'the',
#   'sf',
#   'giants',
#   'won',
#   'the',
#   'world',
#   'series',
#   '?'],
#  ['how', 'long', 'can', 'one', 'be', 'a', 'software', 'engineer', '?'],
#  ['how',
#   'much',
#   'money',
#   'do',
#   'you',
#   'need',
#   'to',
#   'earn',
#   'to',
#   'live',
#   'a',
#   'comfortable',
#   'life',
#   'in',
#   'japan',
#   '?'],
#  ['in',
#   "'",
#   'the',
#   'scarlet',
#   'letter',
#   "',",
#   'why',
#   'was',
#   'chillingworth',
#   'called',
#   'a',
#   'leech',
#   '?'],
#  ['is',
#   'there',
#   'a',
#   'union',
#   'with',
#   'plans',
#   'to',
#   'hold',
#   'union',
#   'organizing',
#   'skill',
#   'training',
#   'for',
#   'low',
#   '-',
#   'wage',
#   'employees',
#   'making',
#   'products',
#   'offshore',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'tell',
#   'my',
#   'parents',
#   'that',
#   'i',
#   'don',
#   "'",
#   't',
#   'believe',
#   'in',
#   'god',
#   '?'],
#  ['do',
#   'we',
#   'need',
#   '"',
#   'share',
#   'a',
#   'comment',
#   '"',
#   'features',
#   'on',
#   'facebook',
#   ',',
#   'what',
#   'do',
#   'you',
#   'think',
#   '?'],
#  ['how', 'is', 'the', 'tsa', 'unconstitutional', '?'],
#  ['how', 'do', 'i', 'find', 'someone', 'by', 'only', 'first', 'name', '?'],
#  ['how',
#   'can',
#   'you',
#   'get',
#   'rid',
#   'of',
#   'a',
#   'boil',
#   'that',
#   'is',
#   'under',
#   'the',
#   'armpit',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'future',
#   'and',
#   'life',
#   'in',
#   'merchant',
#   'navy',
#   'if',
#   'i',
#   'join',
#   '?'],
#  ['who',
#   'are',
#   'some',
#   'excellent',
#   'underground',
#   'hip',
#   '-',
#   'hop',
#   'artists',
#   'specifically',
#   'local',
#   'to',
#   'your',
#   'area',
#   'that',
#   'most',
#   'people',
#   'would',
#   'not',
#   'know',
#   'about',
#   '?'],
#  ['if',
#   'the',
#   'civil',
#   'war',
#   'occurred',
#   'today',
#   'who',
#   'would',
#   'win',
#   '?'],
#  ['what', 'is', 'the', 'best', 'midi', 'keyboard', '?'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'episodes',
#   'of',
#   'pretty',
#   'little',
#   'liars',
#   'season',
#   '4',
#   '?'],
#  ['in',
#   'some',
#   'japanese',
#   'manga',
#   'about',
#   'sports',
#   'or',
#   'fighting',
#   ',',
#   'why',
#   'are',
#   'american',
#   'opponents',
#   'often',
#   'portrayed',
#   'as',
#   'being',
#   'mean',
#   'and',
#   'lacking',
#   'sportsmanship',
#   '?'],
#  ['what',
#   'will',
#   'hillary',
#   'clinton',
#   'do',
#   'about',
#   'climate',
#   'change',
#   '?'],
#  ['is',
#   'the',
#   'pearl',
#   'harbor',
#   '1941',
#   'attack',
#   'a',
#   'hoax',
#   '?',
#   'or',
#   'not',
#   '?'],
#  ['how',
#   'long',
#   'is',
#   'a',
#   'business',
#   'considered',
#   'a',
#   '"',
#   'start',
#   '-',
#   'up',
#   '"',
#   'for',
#   '?'],
#  ['how', 'do', 'i', 'calculate', 'the', 'maximum', 'buffer', 'capacity', '?'],
#  ['how', 'do', 'i', 'spell', 'etc', '.?'],
#  ['did',
#   'later',
#   'mughal',
#   'emperors',
#   '(',
#   'like',
#   'alamgir',
#   'or',
#   'shah',
#   'alam',
#   ')',
#   'speak',
#   'english',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'easiest',
#   'way',
#   'of',
#   'finding',
#   'out',
#   'if',
#   'a',
#   'song',
#   'is',
#   'a',
#   'cover',
#   'version',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'most',
#   'interesting',
#   'products',
#   'and',
#   'innovations',
#   'that',
#   'liberty',
#   'interactive',
#   'is',
#   'coming',
#   'out',
#   'with',
#   'in',
#   '2016',
#   '?'],
#  ['what',
#   'does',
#   'the',
#   'gre',
#   'mean',
#   'by',
#   '"',
#   'once',
#   'every',
#   '21',
#   'days',
#   ',',
#   'up',
#   'to',
#   'five',
#   'times',
#   'within',
#   'any',
#   'continuous',
#   'rolling',
#   '12',
#   '-',
#   'month',
#   'period',
#   '(',
#   '365',
#   'days',
#   ')"?'],
#  ['why', 'is', 'http', 'protocol', 'called', 'stateless', 'protocol', '?'],
#  ['what',
#   'is',
#   'some',
#   'witty',
#   'name',
#   'for',
#   'a',
#   '24hours',
#   'food',
#   'joint',
#   '?'],
#  ['why', 'was', 'cotton', 'known', 'as', '"', 'king', 'cotton', '"?'],
#  ['can',
#   'the',
#   '"',
#   'seen',
#   '"',
#   'mark',
#   'in',
#   'facebook',
#   'chat',
#   'be',
#   'turned',
#   'off',
#   '?'],
#  ['theism',
#   ':',
#   'what',
#   'is',
#   'the',
#   'most',
#   'convincing',
#   'argument',
#   'to',
#   'become',
#   'a',
#   'theist',
#   '?'],
#  ['what',
#   'does',
#   'it',
#   'mean',
#   'when',
#   'i',
#   'get',
#   'an',
#   'update',
#   'from',
#   'quora',
#   'saying',
#   'my',
#   'answer',
#   'was',
#   'moved',
#   '?'],
#  ['can',
#   'china',
#   'actually',
#   'surpass',
#   'usa',
#   'as',
#   'the',
#   'superpower',
#   '?'],
#  ['where', 'can', 'i', 'catch', 'a', 'tauros', 'in', 'pokémon', 'go', '?'],
#  ['how',
#   'do',
#   'you',
#   'start',
#   'a',
#   'wikipedia',
#   'page',
#   'about',
#   'a',
#   'company',
#   '?'],
#  ['what', 'do', 'radio', 'station', 'call', 'letters', 'mean', '?'],
#  ['why',
#   'does',
#   'quora',
#   'allow',
#   'people',
#   'to',
#   'merge',
#   'my',
#   'question',
#   'with',
#   'others',
#   'without',
#   'my',
#   'consent',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'arguments',
#   'for',
#   'pro',
#   'or',
#   'anti',
#   'monarchy',
#   'in',
#   'britain',
#   '?'],
#  ['what',
#   'was',
#   'the',
#   'production',
#   'of',
#   'artwork',
#   'intended',
#   'for',
#   'in',
#   'hawaii',
#   'and',
#   'how',
#   'is',
#   'it',
#   'compared',
#   'to',
#   'the',
#   'one',
#   'intended',
#   'for',
#   'in',
#   'alaska',
#   '?'],
#  ['how', 'do', 'you', 'build', 'a', 'bench', 'press', '?'],
#  ['what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'an',
#   '"',
#   'account',
#   'manager',
#   '"',
#   'and',
#   '"',
#   'accounts',
#   'manager',
#   '"?'],
#  ['can',
#   'we',
#   'control',
#   'our',
#   'dreams',
#   '?',
#   'can',
#   'we',
#   'dream',
#   'what',
#   'we',
#   'wanna',
#   'dream',
#   'about',
#   '?'],
#  ['what', 'is', 'the', 'difference', 'between', 'mppt', 'and', 'pwm', '?'],
#  ['what',
#   'are',
#   'the',
#   'most',
#   'common',
#   'causes',
#   'of',
#   'fires',
#   'in',
#   'houses',
#   '?'],
#  ['can',
#   'i',
#   'deposit',
#   'money',
#   'at',
#   'a',
#   'sbi',
#   'branch',
#   'which',
#   'is',
#   'not',
#   'my',
#   'home',
#   'branch',
#   '?'],
#  ['what',
#   'led',
#   'fox',
#   'to',
#   'accept',
#   'new',
#   'girl',
#   'on',
#   'the',
#   'first',
#   'place',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'dangers',
#   'of',
#   'alpha',
#   'radiation',
#   '?',
#   'why',
#   'are',
#   'they',
#   'dangerous',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'opt',
#   'out',
#   'from',
#   'life',
#   'insurance',
#   'investment',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'way',
#   'to',
#   'ruffle',
#   'someone',
#   "'",
#   's',
#   'feathers',
#   '?'],
#  ['what', 'is', 'the', 'remedy', 'for', 'prolonged', 'knee', 'pain', '?'],
#  ['i',
#   'wan',
#   'to',
#   'enter',
#   'into',
#   'an',
#   'rsi',
#   '.',
#   'how',
#   'can',
#   'i',
#   'enter',
#   'into',
#   'an',
#   'rsi',
#   '?'],
#  ['what',
#   'would',
#   'happen',
#   'if',
#   'gene',
#   'expression',
#   'was',
#   'not',
#   'regulated',
#   '?'],
#  ['what', 'similes', 'does', 'the', 'iliad', 'have', '?'],
#  ['to',
#   'what',
#   'extent',
#   'does',
#   'your',
#   'undergraduate',
#   'college',
#   'have',
#   'an',
#   'influence',
#   'on',
#   'med',
#   'school',
#   'acceptances',
#   '?'],
#  ['how', 'can', 'i', 'become', 'famous', 'one', 'day', '?'],
#  ['i',
#   'want',
#   'to',
#   'update',
#   'kyc',
#   'in',
#   'sbi',
#   'bank',
#   'if',
#   'i',
#   'already',
#   'have',
#   'another',
#   'account',
#   'wirh',
#   'same',
#   'name',
#   'and',
#   'id',
#   'in',
#   'sbi',
#   'itself',
#   '?'],
#  ['do',
#   'we',
#   'have',
#   'great',
#   'people',
#   'who',
#   'aren',
#   "'",
#   't',
#   'patriotic',
#   '?'],
#  ['what', 'is', 'the', 'hiring', 'process', 'like', 'at', 'github', '?'],
#  ['how',
#   'do',
#   'i',
#   'work',
#   'out',
#   'when',
#   'i',
#   'have',
#   'no',
#   'motivation',
#   'to',
#   'work',
#   'out',
#   '?'],
#  ['how',
#   'are',
#   'non',
#   '-',
#   'identical',
#   'twins',
#   'made',
#   '?',
#   'how',
#   'does',
#   'that',
#   'differ',
#   'from',
#   'identical',
#   'twins',
#   '?'],
#  ['could',
#   'you',
#   'recommend',
#   'me',
#   'a',
#   'book',
#   'for',
#   'acid',
#   '-',
#   'base',
#   'reactions',
#   'in',
#   'organic',
#   'chemistry',
#   '?'],
#  ['what',
#   'are',
#   'good',
#   'research',
#   'topics',
#   'in',
#   'machine',
#   'learning',
#   'in',
#   '2016',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'career',
#   'options',
#   'after',
#   'graduation',
#   '(',
#   'b',
#   '.',
#   'sc',
#   'computer',
#   'science',
#   ')',
#   '?',
#   '.',
#   'i',
#   'like',
#   'computers',
#   ',',
#   'pschylogy',
#   'and',
#   'defense',
#   'services'],
#  ['what', 'is', 'it', 'like', 'to', 'be', 'an', 'attractive', 'woman', '?'],
#  ['what',
#   'does',
#   'a',
#   'green',
#   'dot',
#   'by',
#   'the',
#   'phone',
#   'icon',
#   'mean',
#   'on',
#   'messenger',
#   '?'],
#  ['how', 'well', 'has', 'bill', 'de', 'blasio', 'managed', 'nyc', '?'],
#  ['what',
#   'are',
#   'the',
#   'things',
#   'one',
#   'can',
#   'do',
#   'after',
#   'an',
#   'm',
#   '.',
#   'tech',
#   'in',
#   'software',
#   'engineering',
#   '(',
#   'from',
#   'bits',
#   'pilani',
#   ')',
#   'inside',
#   'and',
#   'outside',
#   'of',
#   'india',
#   '?'],
#  ['what',
#   'individuals',
#   'and',
#   'events',
#   'in',
#   'history',
#   'are',
#   'a',
#   'source',
#   'of',
#   'pride',
#   'for',
#   'albania',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'windows',
#   '7',
#   'professional',
#   'and',
#   'windows',
#   '7',
#   'ultimate',
#   '?'],
#  ['how', 'do', 'you', 'make', 'a', 'dynamic', 'webpage', 'in', 'express', '?'],
#  ['what',
#   'app',
#   'will',
#   'let',
#   'me',
#   'download',
#   'free',
#   'songs',
#   'on',
#   'my',
#   'iphone',
#   '?'],
#  ['if',
#   'you',
#   'had',
#   '100',
#   'billion',
#   'dollars',
#   'and',
#   'you',
#   'knew',
#   'that',
#   'you',
#   'would',
#   'always',
#   'live',
#   'like',
#   'a',
#   'multi',
#   '-',
#   'billionaire',
#   ',',
#   'what',
#   'would',
#   'be',
#   'the',
#   'first',
#   'thing',
#   'that',
#   'you',
#   'would',
#   'do',
#   'with',
#   'that',
#   'money',
#   '?'],
#  ['is',
#   'there',
#   'any',
#   'negative',
#   'mark',
#   'for',
#   'ias',
#   'exam',
#   'prelims',
#   'and',
#   'mains',
#   '?'],
#  ['how', 'do', 'you', 'become', 'pretty', '/', 'attractive', '?'],
#  ['what',
#   'are',
#   'the',
#   'top',
#   '10',
#   'films',
#   'every',
#   'film',
#   'lover',
#   'should',
#   'see',
#   '?'],
#  ['is',
#   'six',
#   'hours',
#   'of',
#   'sleep',
#   'enough',
#   'for',
#   'a',
#   '11',
#   'year',
#   'old',
#   '?'],
#  ['why', 'don', "'", 't', 'muslim', 'men', 'wear', 'hijab', '?'],
#  ['how', 'do', 'private', 'equity', 'funds', 'work', 'in', 'film', '?'],
#  ['how',
#   'can',
#   'i',
#   'make',
#   'money',
#   'off',
#   'of',
#   '$',
#   '1000',
#   'in',
#   'the',
#   'stock',
#   'market',
#   '?'],
#  ['is',
#   'it',
#   'disrespectful',
#   'to',
#   'laugh',
#   'hysterically',
#   'in',
#   'a',
#   'public',
#   'place',
#   '?'],
#  ['what',
#   'does',
#   'the',
#   'expression',
#   '"',
#   'the',
#   'whole',
#   'nine',
#   'yards',
#   '"',
#   'mean',
#   '?'],
#  ['where', 'can', 'i', 'play', 'table', 'tennis', 'in', 'dubai', '?'],
#  ['what',
#   'is',
#   'the',
#   'meaning',
#   'of',
#   'the',
#   'telugu',
#   'word',
#   'prayam',
#   'and',
#   'tamakam',
#   '?'],
#  ['should',
#   'i',
#   'leave',
#   'my',
#   'depressed',
#   'girlfriend',
#   'because',
#   'she',
#   'told',
#   'me',
#   'she',
#   'wants',
#   'to',
#   'end',
#   'it',
#   'because',
#   'she',
#   'doesn',
#   "'",
#   't',
#   'want',
#   'to',
#   'hurt',
#   'me',
#   'anymore',
#   '?'],
#  ['i',
#   'am',
#   'a',
#   'home',
#   '-',
#   'maker',
#   '.',
#   'i',
#   'have',
#   'not',
#   'studied',
#   'much',
#   ',',
#   'but',
#   'i',
#   'want',
#   'to',
#   'earn',
#   'money',
#   'without',
#   'going',
#   'out',
#   '.',
#   'how',
#   'can',
#   'i',
#   'earn',
#   'money',
#   'from',
#   'home',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'shia',
#   'and',
#   'sunni',
#   'method',
#   'of',
#   'collecting',
#   'hadith',
#   '?'],
#  ['should', 'i', 'do', 'a', 'thiel', 'fellowship', 'or', 'college', '?'],
#  ['what',
#   'material',
#   'should',
#   'i',
#   'use',
#   'to',
#   'pass',
#   'the',
#   'c2180',
#   '-',
#   '377',
#   'exam',
#   '?'],
#  ['is',
#   'it',
#   'legal',
#   'for',
#   'rental',
#   'company',
#   ',',
#   'to',
#   'track',
#   'my',
#   'rental',
#   'car',
#   'location',
#   'using',
#   'gps',
#   'without',
#   'my',
#   'notice',
#   '?'],
#  ['is', 'c', '++', 'a', 'good', 'language', 'for', 'machine', 'learning', '?'],
#  ['what',
#   'are',
#   'some',
#   'facts',
#   'about',
#   'india',
#   'that',
#   'indians',
#   'are',
#   'generally',
#   'unaware',
#   'of',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'pros',
#   'and',
#   'cons',
#   'of',
#   'being',
#   'a',
#   'girl',
#   'in',
#   'india',
#   '?'],
#  ['what',
#   'do',
#   'you',
#   'do',
#   'to',
#   'spy',
#   'on',
#   'facebook',
#   'messages',
#   'without',
#   'a',
#   'target',
#   'phone',
#   '?'],
#  ['can', 'we', 'use', 'css', 'styles', 'on', 'javascript', 'variables', '?'],
#  ['what', 'is', 'the', 'best', 'way', 'to', 'soft', 'boil', 'an', 'egg', '?'],
#  ['how',
#   'do',
#   'i',
#   'start',
#   'to',
#   'read',
#   'word',
#   'power',
#   'made',
#   'easy',
#   'by',
#   'norman',
#   'lewis',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'ways',
#   'to',
#   'start',
#   'investing',
#   'in',
#   'share',
#   'market',
#   '?'],
#  ['is', 'religion', 'brainwashing', '?'],
#  ['how', 'can', 'a', 'scab', 'inside', 'an', 'ear', 'be', 'treated', '?'],
#  ['what', 'secrets', 'do', 'women', 'not', 'want', 'men', 'to', 'know', '?'],
#  ['i',
#   'really',
#   'want',
#   'to',
#   'become',
#   'a',
#   'pilot',
#   '.',
#   'i',
#   'am',
#   '15',
#   'years',
#   'old',
#   'and',
#   'i',
#   'want',
#   'to',
#   'know',
#   'the',
#   'steps',
#   'to',
#   'becoming',
#   'a',
#   'commercial',
#   'pilot',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'language',
#   'to',
#   'teach',
#   'concepts',
#   'and',
#   'good',
#   'code',
#   '?'],
#  ['what', 'do', 'you', 'think', 'about', 'attn', '.', 'me', '?'],
#  ['what',
#   'is',
#   'the',
#   'relation',
#   'between',
#   'sun',
#   'and',
#   'eyes',
#   'per',
#   'vedas',
#   '?'],
#  ['my',
#   'boyfriend',
#   'avoided',
#   'me',
#   'for',
#   'half',
#   'a',
#   'month',
#   'but',
#   'when',
#   'i',
#   'decided',
#   'to',
#   'break',
#   'up',
#   'with',
#   'him',
#   ',',
#   'he',
#   'became',
#   'affectionate',
#   'all',
#   'of',
#   'a',
#   'sudden',
#   '.',
#   'what',
#   'does',
#   'this',
#   'mean',
#   '?'],
#  ['what', 'makes', 'hamilton', 'the', 'musical', 'so', 'great', '?'],
#  ['why',
#   'do',
#   'muslim',
#   '-',
#   'majority',
#   'nations',
#   'seem',
#   'often',
#   'to',
#   'be',
#   'at',
#   'war',
#   'with',
#   'their',
#   'non',
#   '-',
#   'muslim',
#   'neighbors',
#   'and',
#   'internal',
#   'minorities',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'most',
#   'successful',
#   'treatment',
#   'for',
#   'any',
#   'cancer',
#   '?'],
#  ['how',
#   'do',
#   'you',
#   'fix',
#   'a',
#   'broken',
#   'finger',
#   'that',
#   'healed',
#   'crooked',
#   '?'],
#  ['why', 'do', 'sphynx', 'cats', 'leave', 'brown', 'marks', '?'],
#  ['how', 'has', 'dmt', 'changed', 'your', 'life', '?'],
#  ['how', 'can', 'i', 'self', 'publish', 'book', 'in', 'austria', '?'],
#  ['why', 'is', 'lambswool', 'itchy', '?'],
#  ['should',
#   'i',
#   'dump',
#   'my',
#   'girlfriend',
#   'because',
#   'she',
#   'still',
#   'cares',
#   'for',
#   'her',
#   'ex',
#   'boyfriend',
#   '?'],
#  ['what', 'is', 'the', 'spiritual', 'value', 'of', 'halloween', '?'],
#  ['pull',
#   'three',
#   'blocks',
#   'of',
#   'same',
#   'mass',
#   'connected',
#   'with',
#   'each',
#   'other',
#   ',',
#   'with',
#   'f',
#   'force',
#   'and',
#   'the',
#   'acceleration',
#   'is',
#   'a',
#   'so',
#   'how',
#   'much',
#   'force',
#   'will',
#   'act',
#   'on',
#   'the',
#   'middle',
#   'one',
#   '?'],
#  ['occasionally',
#   'i',
#   'feel',
#   'a',
#   'sharp',
#   'pain',
#   'near',
#   'where',
#   'i',
#   'think',
#   'my',
#   'heart',
#   'is',
#   'and',
#   'when',
#   'i',
#   'inhale',
#   'it',
#   "'",
#   's',
#   'painful',
#   ',',
#   'but',
#   'goes',
#   'away',
#   'after',
#   'a',
#   'few',
#   'seconds',
#   '.',
#   'is',
#   'this',
#   'a',
#   'bad',
#   'sign',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'hottest',
#   'startups',
#   'in',
#   'the',
#   'seattle',
#   'in',
#   '2015',
#   '?'],
#  ['how',
#   'are',
#   'the',
#   'placements',
#   'at',
#   'manipal',
#   'university',
#   'jaipur',
#   '?'],
#  ['why',
#   'is',
#   'it',
#   'so',
#   'uncomfortable',
#   'to',
#   'eat',
#   'with',
#   'a',
#   'palate',
#   'expander',
#   '?'],
#  ['how', 'can', 'music', 'help', 'people', 'with', 'ocd', '?'],
#  ['i',
#   'lost',
#   'my',
#   'social',
#   'security',
#   'card',
#   'a',
#   'few',
#   'months',
#   'ago',
#   ',',
#   'what',
#   'should',
#   'i',
#   'do',
#   '?'],
#  ['who', 'is', 'the', 'founder', 'of', 'zero', '?'],
#  ['what',
#   'are',
#   'the',
#   'pros',
#   'and',
#   'cons',
#   'of',
#   'ruby',
#   'on',
#   'rails',
#   '?'],
#  ['what', 'is', 'startrating', '.', 'com', '?'],
#  ['what', 'is', 'the', 'salary', 'of', 'the', 'pm', 'of', 'india', '?'],
#  ['is',
#   'google',
#   'adwords',
#   'dropping',
#   'google',
#   '+',
#   'from',
#   'search',
#   'ads',
#   '?'],
#  ['textbooks', 'for', '"', 'relativistic', 'quantum', 'mechanics', '"?'],
#  ['what', 'are', 'de', 'broghlie', 'matter', 'wave', '?'],
#  ['what', 'is', 'the', 'example', 'of', 'analogy', '?'],
#  ['what',
#   'happened',
#   'to',
#   'ritchie',
#   'valen',
#   "'",
#   's',
#   'family',
#   'after',
#   'ritchie',
#   'died',
#   '?'],
#  ['what', 'is', '1', '/', '2', '+', '1', '/', '2', '?'],
#  ['i',
#   'am',
#   'planning',
#   'to',
#   'start',
#   'an',
#   'online',
#   'grocery',
#   'store',
#   '.',
#   'what',
#   'are',
#   'the',
#   'steps',
#   'to',
#   'be',
#   'taken',
#   'to',
#   'start',
#   'the',
#   'online',
#   'grocery',
#   'store',
#   '?'],
#  ['i',
#   "'",
#   'm',
#   '35',
#   '.',
#   'how',
#   'much',
#   'money',
#   'should',
#   'i',
#   'have',
#   'saved',
#   'for',
#   'retirement',
#   '?'],
#  ['is', 'odisha', 'developing', '?'],
#  ['which', 'are', 'the', 'best', 'universities', 'in', 'usa', '?'],
#  ['what',
#   'are',
#   'some',
#   'places',
#   'that',
#   'i',
#   'can',
#   'visit',
#   'in',
#   'chennai',
#   'with',
#   'my',
#   'girlfriend',
#   '?'],
#  ['what', 'is', 'your', 'review', 'of', 'pan', 'card', '?'],
#  ['international', 'awards', 'of', 'shahrukh', 'khan', '?'],
#  ['how', 'difficult', 'is', 'it', 'to', 'be', 'a', 'doctor', '?'],
#  ['what',
#   'dishes',
#   'best',
#   'represent',
#   'canada',
#   "'",
#   's',
#   'history',
#   'and',
#   'culture',
#   '?'],
#  ['how', 'can', 'i', 'find', 'launchpad', 'on', 'my', 'macbook', 'air', '?'],
#  ['i',
#   'bought',
#   'a',
#   'second',
#   'hand',
#   'hyundai',
#   'i10',
#   'from',
#   'chennai',
#   '.',
#   'the',
#   'a',
#   '/',
#   'c',
#   'is',
#   'making',
#   'more',
#   'noise',
#   'while',
#   'on',
#   '.',
#   'how',
#   'much',
#   'it',
#   'will',
#   'cost',
#   'to',
#   'replace',
#   'the',
#   'whole',
#   'unit',
#   '?'],
#  ['i',
#   'have',
#   'scored',
#   '138',
#   'in',
#   'neet',
#   '2016',
#   ',',
#   'i',
#   'am',
#   'sc',
#   'candidate',
#   ',',
#   'what',
#   'can',
#   'be',
#   'my',
#   'rank',
#   'or',
#   'can',
#   'i',
#   'get',
#   'admission',
#   'to',
#   'any',
#   'private',
#   'college',
#   '?'],
#  ['what',
#   'time',
#   'gap',
#   'should',
#   'i',
#   'maintain',
#   'between',
#   'yoga',
#   'and',
#   'having',
#   'food',
#   '?'],
#  ['how',
#   'much',
#   'salary',
#   'is',
#   'enough',
#   'to',
#   'live',
#   'comfortably',
#   'in',
#   'saudi',
#   '?'],
#  ['how', 'should', 'i', 'propose', 'my', 'girlfriend', 'mathematically', '?'],
#  ['if',
#   'we',
#   'were',
#   'completely',
#   'able',
#   'to',
#   'control',
#   'our',
#   'emotions',
#   'and',
#   'feelings',
#   ',',
#   'do',
#   'you',
#   'think',
#   'it',
#   'would',
#   'make',
#   'our',
#   'lives',
#   'better',
#   'or',
#   'worse',
#   '?',
#   'why',
#   '?'],
#  ['is', 'corruption', 'mixing', 'things', 'up', '?'],
#  ['do', 'cats', 'and', 'dogs', 'prefer', 'to', 'be', 'domesticated', '?'],
#  ['why', 'did', 'animals', 'evolve', 'to', 'need', 'sleep', '?'],
#  ['how',
#   'do',
#   'i',
#   'wish',
#   'someone',
#   'a',
#   'happy',
#   'birthday',
#   'anonymously',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'scope',
#   'of',
#   'biotechnology',
#   'in',
#   'the',
#   'usa',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'perform',
#   'well',
#   'in',
#   'an',
#   'interview',
#   'of',
#   'ias',
#   '?'],
#  ['how',
#   'many',
#   'phyla',
#   'are',
#   'there',
#   'within',
#   'the',
#   'archaea',
#   '?',
#   'what',
#   'are',
#   'the',
#   'arguments',
#   'for',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'unarchive',
#   'a',
#   'conversation',
#   'on',
#   'facebook',
#   'messenger',
#   '?'],
#  ['how',
#   'many',
#   'is',
#   'too',
#   'many',
#   'illegal',
#   'immigrants',
#   'and',
#   'how',
#   'will',
#   'america',
#   'preserve',
#   'its',
#   'borders',
#   'and',
#   'identity',
#   'as',
#   'a',
#   'nation',
#   '?'],
#  ['when',
#   'a',
#   'motor',
#   'vehicle',
#   'speed',
#   'is',
#   'limited',
#   'by',
#   'law',
#   ',',
#   'then',
#   'why',
#   'do',
#   'manufacturers',
#   'design',
#   'cars',
#   'that',
#   'can',
#   'go',
#   'significantly',
#   'above',
#   'that',
#   'limit',
#   '?'],
#  ['how', 'can', 'someone', 'invent', 'a', 'time', 'machine', '?'],
#  ['what', 'is', 'it', 'like', 'to', 'be', 'a', 'sociology', 'professor', '?'],
#  ['if',
#   'you',
#   'block',
#   'someone',
#   'on',
#   'quora',
#   ',',
#   'can',
#   'they',
#   'still',
#   'comment',
#   'on',
#   'your',
#   'board',
#   'posts',
#   '?'],
#  ['what', 'was', 'combat', 'like', 'in', 'the', 'vietnam', 'war', '?'],
#  ['how', 'do', 'tech', 'startups', 'file', 'patents', '?'],
#  ['what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'sociology',
#   'and',
#   'journalism',
#   '?'],
#  ['how',
#   'do',
#   'you',
#   'counter',
#   'the',
#   'impostor',
#   'syndrome',
#   'in',
#   'grad',
#   'school',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'advantages',
#   'and',
#   'disadvantages',
#   'of',
#   'copywriting',
#   '?'],
#  ['what', 'are', 'some', 'of', 'the', 'best', 'extempore', 'topics', '?'],
#  ['how',
#   'much',
#   'is',
#   'one',
#   'million',
#   'and',
#   'one',
#   'billion',
#   'in',
#   'lakhs',
#   'and',
#   'crores',
#   '?'],
#  ['what',
#   'type',
#   'or',
#   'genre',
#   'of',
#   'music',
#   'is',
#   'this',
#   'and',
#   'how',
#   'can',
#   'i',
#   'find',
#   'more',
#   'music',
#   'similar',
#   'to',
#   'this',
#   'one',
#   '?'],
#  ['for',
#   'how',
#   'many',
#   'days',
#   'can',
#   'a',
#   'person',
#   'survive',
#   'without',
#   'food',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'meaning',
#   'of',
#   'the',
#   'word',
#   'paresham',
#   '(',
#   'its',
#   'a',
#   'hindi',
#   'name',
#   ')?'],
#  ['how',
#   'can',
#   'i',
#   'make',
#   '100',
#   ',',
#   '000',
#   'in',
#   '1',
#   'month',
#   'gambling',
#   '?'],
#  ['what',
#   'are',
#   '5',
#   'natural',
#   'resources',
#   'used',
#   'for',
#   'civilization',
#   '?'],
#  ['is',
#   'it',
#   'really',
#   'possible',
#   'to',
#   'forget',
#   'someone',
#   'you',
#   'loved',
#   'more',
#   'than',
#   'anything',
#   'else',
#   'on',
#   'this',
#   'earth',
#   '?'],
#  ['how', 'do', 'i', 'become', 'a', 'cloud', 'engineer', '?'],
#  ['what',
#   'is',
#   'the',
#   'most',
#   'expensive',
#   'semi',
#   '-',
#   'commonly',
#   'eaten',
#   'dish',
#   '?'],
#  ['one',
#   'of',
#   'my',
#   'closest',
#   'male',
#   'friends',
#   'needs',
#   'to',
#   'update',
#   'his',
#   'fashion',
#   'style',
#   '.',
#   'how',
#   'can',
#   'i',
#   'tell',
#   'him',
#   'this',
#   'and',
#   'offer',
#   'some',
#   'help',
#   'without',
#   'being',
#   'offensive',
#   '?'],
#  ['can',
#   'anyone',
#   'tell',
#   'me',
#   'about',
#   'the',
#   'new',
#   'credit',
#   'based',
#   'system',
#   'in',
#   'iit',
#   'madras',
#   '?'],
#  ['how', 'do', 'i', 'study', 'history', '?'],
#  ['what', 'are', 'self', 'evolving', 'religions', '?'],
#  ['who',
#   'will',
#   'win',
#   'in',
#   'an',
#   'all',
#   'out',
#   'war',
#   '-',
#   'ra',
#   "'",
#   's',
#   'al',
#   'ghul',
#   'or',
#   'red',
#   'skull',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'repair',
#   'damaged',
#   'hair',
#   'because',
#   'of',
#   'straightener',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'differences',
#   'between',
#   'performing',
#   'comedy',
#   'on',
#   'tv',
#   'versus',
#   'stand',
#   '-',
#   'up',
#   '?'],
#  ['i',
#   'don',
#   "'",
#   't',
#   'have',
#   'enough',
#   'money',
#   'to',
#   'go',
#   'to',
#   'rice',
#   'university',
#   ',',
#   'and',
#   'i',
#   'will',
#   'now',
#   'go',
#   'to',
#   'a',
#   'state',
#   'school',
#   '.',
#   'at',
#   'an',
#   'undergraduate',
#   'level',
#   ',',
#   'am',
#   'i',
#   'at',
#   'a',
#   'disadvantage',
#   '?'],
#  ['what',
#   'is',
#   'city',
#   'compensatory',
#   'allowance',
#   '?',
#   'is',
#   'it',
#   'taxable',
#   'or',
#   'not',
#   '?'],
#  ['how',
#   'would',
#   'the',
#   'world',
#   'be',
#   'different',
#   'if',
#   'we',
#   'never',
#   'split',
#   'the',
#   'atom',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'resources',
#   'to',
#   'learn',
#   'data',
#   'structures',
#   'using',
#   'c',
#   '?'],
#  ['can',
#   'you',
#   'mentor',
#   'someone',
#   'whose',
#   'intrested',
#   'in',
#   'hacking',
#   'and',
#   'is',
#   'currently',
#   'an',
#   'average',
#   'skilled',
#   'programmer',
#   '(',
#   '15years',
#   'of',
#   'age',
#   ')',
#   'in',
#   'kenya',
#   '?'],
#  ['is',
#   'interstellar',
#   'travel',
#   'is',
#   'possible',
#   'and',
#   'which',
#   'terms',
#   'should',
#   'be',
#   'considered',
#   'for',
#   'travelling',
#   'through',
#   'worm',
#   'hole',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'top',
#   '5',
#   'problems',
#   'faced',
#   'by',
#   'car',
#   'drivers',
#   'on',
#   'the',
#   'road',
#   '?'],
#  ['atheists',
#   ',',
#   'what',
#   'is',
#   'the',
#   'suitable',
#   'reply',
#   'to',
#   'a',
#   'non',
#   '-',
#   'believer',
#   'who',
#   'doesn',
#   "'",
#   't',
#   'believe',
#   'in',
#   'religions',
#   ',',
#   'but',
#   'he',
#   'can',
#   "'",
#   't',
#   'imagine',
#   'his',
#   'life',
#   'without',
#   'existence',
#   'of',
#   'god',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'convince',
#   'my',
#   'boyfriend',
#   'to',
#   'stop',
#   'sagging',
#   'his',
#   'pants',
#   '?'],
#  ['what', 'are', 'the', 'best', 'ways', 'to', 'ward', 'off', 'stress', '?'],
#  ['does', 'quora', 'advertise', '?'],
#  ['is', 'lucius', 'malfoy', 'a', 'parselmouth', '?'],
#  ['when', 'can', 'i', 'meet', 'god', '?'],
#  ['a',
#   'set',
#   'a',
#   'has',
#   '4',
#   'elements',
#   'and',
#   'another',
#   'set',
#   'b',
#   'has',
#   '3',
#   'elements',
#   '.',
#   'what',
#   'is',
#   'the',
#   'probability',
#   'that',
#   'a',
#   'relation',
#   'from',
#   'a',
#   'to',
#   'b',
#   'will',
#   'be',
#   'onto',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'worst',
#   'online',
#   'dating',
#   'sites',
#   'for',
#   'people',
#   'of',
#   'color',
#   '?'],
#  ['what',
#   'is',
#   'a',
#   'good',
#   'summer',
#   'internship',
#   'for',
#   'maths',
#   'students',
#   'in',
#   'india',
#   '?'],
#  ['i',
#   "'",
#   'm',
#   'jealous',
#   'of',
#   'people',
#   'who',
#   'remember',
#   'everything',
#   'they',
#   'read',
#   '.',
#   'how',
#   'do',
#   'i',
#   'overcome',
#   'this',
#   'while',
# ...
#  ['what', 'are', 'the', 'best', 'sex', 'sites', '?'],
#  ['religion',
#   'as',
#   'a',
#   'whole',
#   'teaches',
#   'love',
#   'and',
#   'compassion',
#   '.',
#   'even',
#   'if',
#   'a',
#   'god',
#   'doesn',
#   "'",
#   't',
#   'exist',
#   ',',
#   'why',
#   'do',
#   'people',
#   'resist',
#   'the',
#   'thought',
#   'of',
#   'a',
#   'religious',
#   'mentality',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'raise',
#   'seed',
#   'money',
#   'for',
#   'a',
#   'brilliant',
#   'fintech',
#   'idea',
#   '?'],
#  ['what',
#   'would',
#   'it',
#   'take',
#   'for',
#   'you',
#   'to',
#   'vote',
#   'for',
#   'the',
#   'us',
#   'president',
#   '?'],
#  ['what', 'is', 'mean', 'by', 'infrastructure', '?'],
#  ['how',
#   'do',
#   'i',
#   'use',
#   'import',
#   'node',
#   '.',
#   'js',
#   'in',
#   'unity',
#   '3d',
#   '?'],
#  ['pokemon', 'go', 'hack', '?'],
#  ['what',
#   'is',
#   'the',
#   'difference',
#   'between',
#   'tablets',
#   'and',
#   'pills',
#   '?'],
#  ['what', 'is', 'a', 'market', 'space', '?'],
#  ['can', 'tortoises', 'eat', 'blueberries', '?', 'why', '?'],
#  ['is', 'actualtests', '.', 'com', 'a', 'scam', '?'],
#  ['is',
#   'there',
#   'anything',
#   'you',
#   'can',
#   'take',
#   'to',
#   'pass',
#   'a',
#   'urine',
#   'test',
#   'for',
#   'meth',
#   '?'],
#  ['why',
#   'was',
#   'i',
#   'born',
#   '?',
#   'what',
#   'am',
#   'i',
#   '?',
#   'why',
#   'wasn',
#   "'",
#   't',
#   'i',
#   'born',
#   'this',
#   'person',
#   'or',
#   'that',
#   'person',
#   ',',
#   'or',
#   'a',
#   'lion',
#   'or',
#   'dog',
#   'or',
#   'any',
#   'other',
#   'animal',
#   ',',
#   'whether',
#   'in',
#   'the',
#   'present',
#   ',',
#   'future',
#   'or',
#   'past',
#   '?'],
#  ['leeco',
#   'le',
#   'max2',
#   'vs',
#   'oneplus',
#   '3',
#   ',',
#   'which',
#   'one',
#   'should',
#   'you',
#   'buy',
#   '?'],
#  ['should',
#   'i',
#   'commit',
#   'suicide',
#   'if',
#   'i',
#   'failed',
#   'in',
#   'my',
#   'final',
#   'exams',
#   '?'],
#  ['what',
#   'is',
#   'apple',
#   "'",
#   's',
#   'corporate',
#   'slogan',
#   '?',
#   'what',
#   'does',
#   'it',
#   'mean',
#   '?'],
#  ['what',
#   'turns',
#   'you',
#   'on',
#   'sexually',
#   'as',
#   'a',
#   'woman',
#   'or',
#   'girl',
#   '?'],
#  ['how',
#   'do',
#   'we',
#   'change',
#   'the',
#   'legal',
#   'age',
#   'from',
#   '18',
#   'to',
#   '25',
#   'considering',
#   'brains',
#   'aren',
#   "'",
#   't',
#   'fully',
#   'developed',
#   'until',
#   'then',
#   '.?'],
#  ['what',
#   'percent',
#   'of',
#   'smokers',
#   'develop',
#   'cancer',
#   'vs',
#   'non',
#   'smokers',
#   '?'],
#  ['who', 'is', 'the', 'greatest', 'badass', 'in', 'history', '?'],
#  ['how', 'can', 'a', 'street', 'photographer', 'get', 'paid', '?'],
#  ['will', 'the', 'us', 'invade', 'california', '?'],
#  ['what',
#   'is',
#   'the',
#   'maximum',
#   'temperature',
#   'stability',
#   'of',
#   'carbon',
#   'fiber',
#   'composite',
#   'and',
#   'glass',
#   'fiber',
#   'composite',
#   '?'],
#  ['how',
#   'much',
#   'has',
#   'your',
#   'salary',
#   'increased',
#   'from',
#   'your',
#   'first',
#   'job',
#   'to',
#   'today',
#   '?'],
#  ['is', "'", 'complacent', "'", 'a', 'negative', 'word', '?'],
#  ['which', 'is', 'the', 'best', 'indian', 'patriotic', 'song', '?'],
#  ['what', 'do', 'you', 'enjoy', 'about', 'sex', '?'],
#  ['men',
#   ',',
#   'honest',
#   'advice',
#   '..',
#   'why',
#   'won',
#   "'",
#   't',
#   'he',
#   'give',
#   'up',
#   'pursuing',
#   'me',
#   'after',
#   'two',
#   'years',
#   '?'],
#  ['how',
#   'can',
#   'i',
#   'access',
#   'a',
#   'device',
#   'on',
#   'the',
#   'same',
#   'wi',
#   '-',
#   'fi',
#   'network',
#   'without',
#   'knowing',
#   'its',
#   'password',
#   '(',
#   'hack',
#   ')?'],
#  ['what',
#   'would',
#   'be',
#   'some',
#   'extremely',
#   'warm',
#   'socks',
#   'that',
#   'can',
#   'be',
#   'worn',
#   'with',
#   'a',
#   'barefoot',
#   'style',
#   'of',
#   'running',
#   'shoes',
#   '?'],
#  ['when',
#   'did',
#   'the',
#   'laws',
#   'change',
#   'to',
#   'if',
#   'you',
#   "'",
#   're',
#   'convicted',
#   'of',
#   'a',
#   'law',
#   'your',
#   'gun',
#   'ownership',
#   'is',
#   'taken',
#   'away',
#   '?',
#   'and',
#   'how',
#   'do',
#   'you',
#   'get',
#   'your',
#   'owning',
#   'a',
#   'firearm',
#   'rights',
#   'restored',
#   '?'],
#  ['why',
#   'do',
#   'lot',
#   'of',
#   'people',
#   'don',
#   "'",
#   't',
#   'follow',
#   'the',
#   'principles',
#   'of',
#   'swami',
#   'vivekananda',
#   '?'],
#  ['what',
#   'does',
#   'it',
#   'mean',
#   'if',
#   'my',
#   'ex',
#   'likes',
#   'all',
#   'of',
#   'my',
#   'facebook',
#   'statuses',
#   'and',
#   'pictures',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'alternatives',
#   'to',
#   'subtlepatterns',
#   '.',
#   'com',
#   '?'],
#  ['can',
#   'i',
#   'use',
#   'the',
#   'simple',
#   'past',
#   'tense',
#   'instead',
#   'of',
#   'the',
#   'present',
#   'perfect',
#   'tense',
#   'in',
#   'these',
#   'sentences',
#   '?'],
#  ['what', 'does', 'a', 'communications', 'manager', 'do', '?'],
#  ['in',
#   'the',
#   'crossroads',
#   'scene',
#   'in',
#   'the',
#   'movie',
#   'cast',
#   'away',
#   ',',
#   'did',
#   'chuck',
#   'end',
#   'up',
#   'going',
#   'back',
#   'to',
#   'that',
#   'women',
#   'with',
#   'the',
#   'wings',
#   'symbol',
#   '?'],
#  ['which',
#   'is',
#   'a',
#   'suitable',
#   'inpatient',
#   'drug',
#   'and',
#   'alcohol',
#   'rehab',
#   'center',
#   'in',
#   'lyon',
#   'county',
#   'ky',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'most',
#   'asked',
#   'question',
#   'in',
#   'an',
#   'interview',
#   '?'],
#  ['how', 'do', 'you', 'livestream', 'instagram', 'hashtags', '?'],
#  ['is',
#   'bel',
#   'an',
#   'appropriate',
#   'firm',
#   'for',
#   'doing',
#   'summer',
#   'training',
#   'by',
#   'a',
#   'mechanical',
#   'engineer',
#   '?'],
#  ['if',
#   'i',
#   'delete',
#   'someone',
#   'from',
#   'my',
#   'snapchat',
#   'friend',
#   'list',
#   ',',
#   'will',
#   'he',
#   'be',
#   'able',
#   'to',
#   'see',
#   'my',
#   'best',
#   'friends',
#   'list',
#   '?'],
#  ['how',
#   'popular',
#   'were',
#   'public',
#   'executions',
#   'as',
#   'entertainment',
#   'in',
#   'the',
#   'europe',
#   'of',
#   'the',
#   '19th',
#   'century',
#   '?'],
#  ['which', 'is', 'good', 'part', 'time', 'job', 'in', 'chennai', '?'],
#  ['why', 'some', 'people', 'commit', 'suicide', '?'],
#  ['is',
#   'it',
#   'legal',
#   'to',
#   'drink',
#   'alcohol',
#   'while',
#   'in',
#   'an',
#   'rv',
#   '?'],
#  ['in',
#   'retrospect',
#   ',',
#   'did',
#   'magic',
#   'johnson',
#   'need',
#   'to',
#   'retire',
#   'from',
#   'the',
#   'nba',
#   'due',
#   'to',
#   'his',
#   'having',
#   'hiv',
#   '?'],
#  ['can',
#   'you',
#   'change',
#   'the',
#   'way',
#   'a',
#   'girl',
#   'thinks',
#   'about',
#   'you',
#   '?'],
#  ['what', 'is', 'elon', 'musk', 'like', 'in', 'person', '?'],
#  ['does',
#   'testosterone',
#   'increase',
#   'in',
#   'a',
#   'man',
#   'just',
#   'by',
#   'talking',
#   'to',
#   'a',
#   'woman',
#   '?'],
#  ['who',
#   'are',
#   'some',
#   'of',
#   'the',
#   'best',
#   'audiobook',
#   'readers',
#   'and',
#   'why',
#   '?'],
#  ['what',
#   'universities',
#   'does',
#   'trillium',
#   'therapeutics',
#   'recruit',
#   'new',
#   'grads',
#   'from',
#   '?',
#   'what',
#   'majors',
#   'are',
#   'they',
#   'looking',
#   'for',
#   '?'],
#  ['is', 'pakistan', 'an', 'islamic', 'nation', '?'],
#  ['how',
#   'did',
#   'apple',
#   'keep',
#   'the',
#   'design',
#   'of',
#   'airpods',
#   'secret',
#   '?'],
#  ['are', 'kayak', 'price', 'alerts', 'useful', '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'touchscreen',
#   'alternative',
#   'to',
#   'a',
#   'macbook',
#   'pro',
#   'in',
#   '2016',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'to',
#   'trace',
#   'a',
#   'phone',
#   'call',
#   'in',
#   'real',
#   'time',
#   'with',
#   'good',
#   'accuracy',
#   '?'],
#  ['why',
#   'did',
#   'it',
#   'take',
#   'so',
#   'long',
#   'for',
#   'nasa',
#   'to',
#   'find',
#   'water',
#   'on',
#   'mars',
#   '?'],
#  ['how',
#   'do',
#   'i',
#   'lose',
#   'belly',
#   'fat',
#   'in',
#   'a',
#   'month',
#   'without',
#   'going',
#   'to',
#   'the',
#   'gym',
#   '?'],
#  ['what', 'is', 'computer', '?'],
#  ['how', 'can', 'i', 'really', 'make', 'money', 'online', '?'],
#  ['does', 'the', 'big', 'bang', 'infinitely', 'repeat', 'itself', '?'],
#  ['what',
#   'should',
#   'everyone',
#   'need',
#   'to',
#   'know',
#   'about',
#   'the',
#   '2014',
#   'yahoo',
#   'hack',
#   '?'],
#  ['what', 'is', 'another', 'name', 'for', 'a', 'nerve', 'cell', '?'],
#  ['which',
#   'are',
#   'the',
#   'three',
#   'more',
#   'realistic',
#   'ways',
#   'to',
#   'become',
#   'a',
#   'multi',
#   'millionaire',
#   'before',
#   '30',
#   '?'],
#  ['what', 'are', 'the', 'rights', 'of', 'a', 'prisoner', '?'],
#  ['what',
#   'are',
#   'the',
#   'monkey',
#   'king',
#   "'",
#   's',
#   'powers',
#   '(',
#   'sun',
#   'wukong',
#   ')?'],
#  ['how',
#   'did',
#   'your',
#   'parents',
#   'react',
#   'when',
#   'they',
#   'came',
#   'to',
#   'know',
#   'that',
#   'you',
#   'lost',
#   'your',
#   'virginity',
#   '?'],
#  ['what',
#   'percentage',
#   'of',
#   'vietnam',
#   "'",
#   's',
#   'culture',
#   'from',
#   'food',
#   ',',
#   'traditions',
#   ',',
#   'etc',
#   'would',
#   'you',
#   'say',
#   'is',
#   'derived',
#   'or',
#   'influenced',
#   'by',
#   'china',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'reasons',
#   'that',
#   'a',
#   'guy',
#   'would',
#   'wear',
#   'thong',
#   'underwear',
#   'instead',
#   'of',
#   'boxers',
#   'or',
#   'briefs',
#   '?'],
#  ['what', 'makes', 'you', 'feel', 'loved', '?'],
#  ['could', 'a', 'psychopath', 'become', 'a', 'good', 'ceo', '?'],
#  ['what', 'is', 't', '.', 's', 'diagram', '?'],
#  ['what',
#   'are',
#   'good',
#   'topics',
#   'for',
#   'an',
#   'architecture',
#   'graduation',
#   'thesis',
#   '?'],
#  ['what', 'are', 'the', 'hottest', 'startups', 'in', 'ireland', '?'],
#  ['when',
#   'light',
#   'bounces',
#   'off',
#   'an',
#   'electron',
#   'in',
#   'the',
#   'compton',
#   'effect',
#   'and',
#   'loses',
#   'energy',
#   '(',
#   'giving',
#   'it',
#   'to',
#   'the',
#   'electron',
#   ')',
#   'wouldn',
#   "'",
#   't',
#   'that',
#   'slow',
#   'it',
#   'down',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'best',
#   'petting',
#   'zoos',
#   'within',
#   'a',
#   'few',
#   'hours',
#   'of',
#   'the',
#   'san',
#   'francisco',
#   'bay',
#   'area',
#   '?'],
#  ['top', 'writers', 'program', '?'],
#  ['what',
#   'is',
#   'supply',
#   'chain',
#   'management',
#   'of',
#   'berger',
#   'and',
#   'nerolac',
#   'paints',
#   '?'],
#  ['i',
#   'have',
#   'a',
#   'salary',
#   'of',
#   '15',
#   'lpa',
#   'with',
#   '3',
#   'years',
#   'experience',
#   ',',
#   'but',
#   'have',
#   'only',
#   'b',
#   '.',
#   'tech',
#   'degree',
#   ',',
#   'do',
#   'i',
#   'have',
#   'to',
#   'pursue',
#   'higher',
#   'studies',
#   'to',
#   'grow',
#   'in',
#   'career',
#   '?'],
#  ['do',
#   'engineering',
#   'classes',
#   'depend',
#   'on',
#   'physics',
#   'and',
#   'calculus',
#   '?'],
#  ['which',
#   'is',
#   'better',
#   'for',
#   'one',
#   "'",
#   's',
#   'life',
#   ',',
#   'knowing',
#   'more',
#   'people',
#   'or',
#   'gaining',
#   'more',
#   'knowledge',
#   '?'],
#  ['which',
#   'is',
#   'better',
#   ',',
#   'chemical',
#   'at',
#   'bits',
#   'goa',
#   'or',
#   'chemical',
#   'at',
#   'bits',
#   'hyderabad',
#   '?'],
#  ['should', 'i', 'quit', 'engineering', '?'],
#  ['who',
#   'makes',
#   'more',
#   'money',
#   ',',
#   'a',
#   'portfolio',
#   'manager',
#   'from',
#   'a',
#   'hedge',
#   'fund',
#   'or',
#   'one',
#   'from',
#   'a',
#   'large',
#   'asset',
#   'manager',
#   ',',
#   'like',
#   'blackrock',
#   'or',
#   'vanguard',
#   '?'],
#  ['origin', 'of', 'udeniya', '(', 'brahmins', ')?'],
#  ['is',
#   'there',
#   'a',
#   'way',
#   'on',
#   'facebook',
#   'to',
#   'unfriend',
#   'someone',
#   'without',
#   'them',
#   'noticing',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'mind',
#   '-',
#   'blowing',
#   'drivers',
#   'accessories',
#   'that',
#   'exist',
#   'that',
#   'most',
#   'people',
#   'don',
#   "'",
#   't',
#   'know',
#   'about',
#   '?'],
#  ['i',
#   'feel',
#   'like',
#   'i',
#   "'",
#   'm',
#   'being',
#   'used',
#   ',',
#   'but',
#   'i',
#   'like',
#   'him',
#   '.',
#   'we',
#   "'",
#   're',
#   'friends',
#   'with',
#   'benefit',
#   '.',
#   'should',
#   'i',
#   'leave',
#   '?'],
#  ['which',
#   'is',
#   'better',
#   ':',
#   'wordpress',
#   ',',
#   'weebly',
#   'or',
#   'blogger',
#   '?'],
#  ['what', 'is', 'the', 'medicine', '(', 'schapo', ')', 'in', 'india', '?'],
#  ['what', 'are', 'different', 'subjects', 'taught', 'in', 'algebra', '1', '?'],
#  ['how',
#   'can',
#   'i',
#   'help',
#   'take',
#   'care',
#   'of',
#   'sore',
#   'muscles',
#   '(',
#   'legs',
#   ')?'],
#  ['what',
#   'is',
#   'the',
#   'typical',
#   'career',
#   'path',
#   'of',
#   'market',
#   'risk',
#   'modeling',
#   '?'],
#  ['how', 'do', 'you', 'drop', 'ship', '?'],
#  ['when', 'will', 'the', 'stock', 'market', 'crash', 'again', '?'],
#  ['isn', "'", 't', 'marriage', 'a', 'necessary', 'evil', '?'],
#  ['what', 'is', 'ashton', 'kutcher', 'doing', 'next', '?'],
#  ['why',
#   'do',
#   'we',
#   'use',
#   'n',
#   '-',
#   'hexane',
#   'in',
#   'thin',
#   'layer',
#   'chromatography',
#   '?'],
#  ['if',
#   'i',
#   'do',
#   'mbbs',
#   'and',
#   'md',
#   'from',
#   'usa',
#   'howcan',
#   'i',
#   'help',
#   'full',
#   '?'],
#  ['what', 'are', 'some', 'stores', 'similar', 'to', 'forever', '21', '?'],
#  ['how',
#   'often',
#   'do',
#   'people',
#   'become',
#   'rich',
#   'thru',
#   'luck',
#   ',',
#   'nepotism',
#   ',',
#   'connections',
#   ',',
#   'rather',
#   'than',
#   'their',
#   'own',
#   'skill',
#   ',',
#   'talent',
#   ',',
#   'or',
#   'hard',
#   'work',
#   '?'],
#  ['what',
#   'are',
#   'three',
#   'key',
#   'economic',
#   'questions',
#   'that',
#   'society',
#   'must',
#   'answer',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'most',
#   'important',
#   'current',
#   'women',
#   "'",
#   's',
#   'rights',
#   'issues',
#   'in',
#   'ethiopia',
#   '?'],
#  ['will',
#   'we',
#   'add',
#   'length',
#   'of',
#   'one',
#   'car',
#   'if',
#   'the',
#   'question',
#   'is',
#   'to',
#   'find',
#   'total',
#   'distance',
#   'used',
#   'for',
#   'overtake',
#   'when',
#   'two',
#   'car',
#   'of',
#   'same',
#   'length',
#   'is',
#   'moving',
#   '.?'],
#  ['what',
#   'can',
#   'i',
#   'do',
#   'if',
#   'i',
#   'ever',
#   'spill',
#   'water',
#   'over',
#   'my',
#   'laptop',
#   '?'],
#  ['what',
#   'are',
#   'some',
#   'mind',
#   '-',
#   'blowing',
#   'technology',
#   'tools',
#   'that',
#   'most',
#   'people',
#   'don',
#   "'",
#   't',
#   'know',
#   'about',
#   '?'],
#  ['i',
#   'believe',
#   'i',
#   'have',
#   'settled',
#   'the',
#   'riemann',
#   'hypothesis',
#   'but',
#   'don',
#   "'",
#   't',
#   'want',
#   'to',
#   'make',
#   'a',
#   'fool',
#   'of',
#   'myself',
#   '.',
#   'how',
#   'should',
#   'i',
#   'proceed',
#   '?'],
#  ['china',
#   ':',
#   'what',
#   'makes',
#   'majority',
#   'of',
#   'china',
#   'so',
#   'poor',
#   'despite',
#   'its',
#   'high',
#   'development',
#   'rate',
#   '?'],
#  ['what',
#   'are',
#   'the',
#   'key',
#   'qualities',
#   'to',
#   'become',
#   'successful',
#   'in',
#   'life',
#   '?',
#   'how',
#   'to',
#   'adopt',
#   'this',
#   'qualities',
#   '?'],
#  ['how', 'much', 'is', 'a', '1962', 'us', 'quarter', 'valued', 'for', '?'],
#  ['why', 'the', 'movie', 'named', 'pink', '?'],
#  ['what',
#   'made',
#   'claude',
#   'debussy',
#   'more',
#   'famous',
#   ':',
#   'his',
#   'works',
#   ',',
#   'or',
#   'the',
#   'impact',
#   'he',
#   'had',
#   'on',
#   'composers',
#   'following',
#   'him',
#   ',',
#   'and',
#   'why',
#   '?'],
#  ['which',
#   'is',
#   'the',
#   'best',
#   'online',
#   'courses',
#   'for',
#   'learning',
#   'mobile',
#   'apps',
#   'and',
#   'web',
#   'designing',
#   '?'],
#  ['how',
#   'does',
#   'the',
#   'chinese',
#   'concept',
#   'of',
#   'chi',
#   'differ',
#   'from',
#   'the',
#   'indian',
#   'equivalent',
#   '"',
#   'prana',
#   '"?'],
#  ['what',
#   'is',
#   'the',
#   'most',
#   'efficient',
#   'sorting',
#   'algorithm',
#   'for',
#   'finding',
#   'largest',
#   'number',
#   'among',
#   '20',
#   'numbers',
#   '?'],
#  ['why',
#   'usa',
#   'goverment',
#   'is',
#   'not',
#   'punished',
#   'because',
#   'of',
#   'it',
#   "'",
#   's',
#   'invansion',
#   'to',
#   'iraq',
#   'even',
#   'the',
#   'reason',
#   'of',
#   'invansion',
#   '(',
#   'biological',
#   'weapon',
#   'ownage',
#   ')',
#   'was',
#   'not',
#   'founded',
#   '?'],
#  ['does', 'social', 'workers', 'have', 'love', 'life', '?'],
#  ['is',
#   'it',
#   'a',
#   'good',
#   'idea',
#   'to',
#   'invest',
#   '90',
#   '%',
#   'of',
#   'your',
#   'time',
#   'in',
#   'studying',
#   '(',
#   'engineering',
#   ')',
#   'from',
#   'the',
#   'ages',
#   'of',
#   '18',
#   'to',
#   '23',
#   'years',
#   'old',
#   '?'],
#  ['is',
#   'iit',
#   'the',
#   'greatest',
#   'tag',
#   'even',
#   'than',
#   'mit',
#   ',',
#   'harvard',
#   ',',
#   'stanford',
#   '..',
#   'etc',
#   '?'],
#  ['why',
#   'do',
#   'table',
#   'and',
#   'ceiling',
#   'fans',
#   'rotate',
#   'in',
#   'the',
#   'opposite',
#   'direction',
#   '?'],
#  ['what',
#   'is',
#   'it',
#   'like',
#   'for',
#   'you',
#   'to',
#   'appear',
#   'much',
#   'younger',
#   'than',
#   'your',
#   'actual',
#   'age',
#   '?'],
#  ['what',
#   'is',
#   'the',
#   'best',
#   'way',
#   'to',
#   'solve',
#   'a',
#   '3x3',
#   'mirror',
#   'cube',
#   '?',
#   'how',
#   'can',
#   'i',
#   'learn',
#   'solving',
#   'it',
#   '?'],
#  ['will',
#   'donating',
#   'blood',
#   'temporarily',
#   'lower',
#   'blood',
#   'pressure',
#   '?'],
#  ['how', 'can', 'i', 'learn', 'marathons', '?']]

# %%
assert all(isinstance(row, (list, tuple)) for row in data_tok), "please convert each line into a list of tokens (strings)"
assert all(all(isinstance(tok, str) for tok in row) for row in data_tok), "please convert each line into a list of tokens (strings)"
is_latin = lambda tok: all('a' <= x.lower() <= 'z' for x in tok)
assert all(map(lambda l: not is_latin(l) or l.islower(), map(' '.join, data_tok))), "please make sure to lowercase the data"

# %%
print([' '.join(row) for row in data_tok[:2]])
# Out:
# ["can i get back with my ex even though she is pregnant with another guy ' s baby ?", 'what are some ways to overcome a fast food addiction ?']

# %% [markdown]
# __Word vectors:__ as the saying goes, there's more than one way to train word embeddings. There's Word2Vec and GloVe with different objective functions. Then there's fastText that uses character-level models to train word embeddings.
#
# The choice is huge, so let's start someplace small: __gensim__ is another NLP library that features many vector-based models including word2vec.

# %%
from gensim.models import Word2Vec
model = Word2Vec(data_tok,
                 vector_size=32,      # embedding vector size
                 min_count=5,         # consider words that occurred at least 5 times
                 window=5).wv         # define context as a 5-word window around the target word

# From gensim docs
# wv: This object essentially contains the mapping between words and embeddings.
# After training, it can be used directly to query those embeddings in various ways.

# %%
# now you can get word vectors !
model.get_vector('anything')
# Out:
# array([-4.9133663 ,  1.161513  ,  0.22053833,  1.3496008 ,  3.3344307 ,
#         1.7184846 ,  2.251789  , -3.9683805 , -0.87442124,  1.3197272 ,
#        -2.2856846 ,  1.1228536 ,  3.098624  ,  0.02234771,  3.2606256 ,
#         0.68956286,  0.45067006,  1.7833104 , -0.6748897 , -1.8955926 ,
#        -1.834292  , -0.79050577, -1.9637605 , -2.2747152 ,  0.5767942 ,
#        -3.4095988 , -0.5037381 , -0.7628215 ,  0.6244543 ,  1.7121469 ,
#        -1.4306692 ,  0.20891538], dtype=float32)

# %%
# or query similar words directly. Go play with it!
model.most_similar('bread')
# Out:
# [('rice', 0.9583238363265991),
#  ('cheese', 0.9372202157974243),
#  ('sauce', 0.9349772930145264),
#  ('potato', 0.9196271300315857),
#  ('corn', 0.9181205034255981),
#  ('chocolate', 0.9138939380645752),
#  ('butter', 0.9129441976547241),
#  ('flour', 0.9081729650497437),
#  ('chicken', 0.9068810343742371),
#  ('soup', 0.9055949449539185)]

# %% [markdown]
# ### Using pre-trained model
#
# Took it a while, huh? Now imagine training life-sized (100~300D) word embeddings on gigabytes of text: Wikipedia articles or Twitter posts.
#
# Thankfully, nowadays you can get a pre-trained word embedding model in 2 lines of code (no SMS required, promise).
#
# After being downloaded for the first time (or if you manually delete it), the model is saved in the `~/gensim_data` or `%USER_PATH%/gensim_data` directory. This can be checked by setting the return_path parameter to True.

# %%
import gensim.downloader as api
model = api.load('glove-twitter-100')

# %%
model.most_similar(positive=["coder", "money"], negative=["brain"])
# Out:
# [('broker', 0.5820155739784241),
#  ('bonuses', 0.5424473285675049),
#  ('banker', 0.5385112762451172),
#  ('designer', 0.5197198390960693),
#  ('merchandising', 0.4964233338832855),
#  ('treet', 0.4922019839286804),
#  ('shopper', 0.4920562207698822),
#  ('part-time', 0.4912828207015991),
#  ('freelance', 0.4843311905860901),
#  ('aupair', 0.4796452522277832)]

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
#
# # Visualizing data with word embeddings (1 point)

# %% [markdown]
# One way to see if our vectors are any good is to plot them. Thing is, those vectors are in 30D+ space and we humans are more used to 2-3D.
#
# Luckily, we machine learners know about __dimensionality reduction__ methods.
#
# Let's use that to plot 1000 most frequent words

# %%
words = model.index_to_key[:1000]

print(words[::100])
# Out:
# ['<user>', '_', 'please', 'apa', 'justin', 'text', 'hari', 'playing', 'once', 'sei']

# %%
# for each word, compute its vector with model
word_vectors = np.array([model.get_vector(word) for word in words])  # YOUR CODE
word_vectors.shape
# Out:
# (1000, 100)

# %%
assert isinstance(word_vectors, np.ndarray)
assert word_vectors.shape == (len(words), 100)
assert np.isfinite(word_vectors).all()

# %% [markdown]
# #### Linear projection: PCA
#
# The simplest linear dimensionality reduction method is **P**rincipal **C**omponent **A**nalysis.
#
# In geometric terms, PCA tries to find axes along which most of the variance occurs. The "natural" axes, if you wish.
#
# <img src="https://github.com/yandexdataschool/Practical_RL/raw/master/yet_another_week/_resource/pca_fish.png" style="width:30%">
#
#
# Under the hood, it attempts to decompose object-feature matrix $X$ into two smaller matrices: $W$ and $\hat W$ minimizing _mean squared error_:
#
# $$\|(X W) \hat{W} - X\|^2_2 \to_{W, \hat{W}} \min$$
# - $X \in \mathbb{R}^{n \times m}$ - object matrix (**centered**);
# - $W \in \mathbb{R}^{m \times d}$ - matrix of direct transformation;
# - $\hat{W} \in \mathbb{R}^{d \times m}$ - matrix of reverse transformation;
# - $n$ samples, $m$ original dimensions and $d$ target dimensions;

# %%
from sklearn.decomposition import PCA

# map word vectors onto 2d plane with PCA. Use good old sklearn API (fit, transform)
# after that, normalize vectors to make sure they have zero mean and unit variance
word_vectors_pca = PCA(n_components=2).fit_transform(word_vectors)   # YOUR CODE
word_vectors_pca

def normalize(x):
    return (x - x.mean(axis=0)) / x.std(axis=0)

word_vectors_pca = normalize(word_vectors_pca)
# and maybe MORE OF YOUR CODE here :)

# %%
assert word_vectors_pca.shape == (len(word_vectors), 2), "there must be a 2d vector for each word"
assert max(abs(word_vectors_pca.mean(0))) < 1e-5, "points must be zero-centered"
assert max(abs(1.0 - word_vectors_pca.std(0))) < 1e-2, "points must have unit variance"

# %% [markdown]
# #### Let's draw it!

# %%
import bokeh.models as bm, bokeh.plotting as pl
from bokeh.io import output_notebook
output_notebook()

def draw_vectors(x, y, radius=10, alpha=0.25, color='blue',
                 width=600, height=400, show=True, **kwargs):
    """ draws an interactive plot for data points with auxilirary info on hover """
    if isinstance(color, str): color = [color] * len(x)
    data_source = bm.ColumnDataSource({ 'x' : x, 'y' : y, 'color': color, **kwargs })

    fig = pl.figure(active_scroll='wheel_zoom', width=width, height=height)
    fig.scatter('x', 'y', size=radius, color='color', alpha=alpha, source=data_source)

    fig.add_tools(bm.HoverTool(tooltips=[(key, "@" + key) for key in kwargs.keys()]))
    if show: pl.show(fig)
    return fig
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="de411c7d-35ee-4618-a4ca-d018d5101f83">Loading BokehJS ...</span>
#     </div>

# %%
draw_vectors(word_vectors_pca[:, 0], word_vectors_pca[:, 1], token=words)

# hover a mouse over there and see if you can identify the clusters
# Out:
#   <div id="a0a4914c-9717-455a-8c60-debf235edc55" data-root-id="p1011" style="display: contents;"></div>
# figure(id='p1011', ...)

# %% [markdown]
# #### Visualizing neighbors with t-SNE
# PCA is nice but it's strictly linear and thus only able to capture coarse high-level structure of the data.
#
# If we instead want to focus on keeping neighboring points near, we could use TSNE, which is itself an embedding method. Here you can read __[more on TSNE](https://distill.pub/2016/misread-tsne/)__.

# %%
from sklearn.manifold import TSNE

# map word vectors onto 2d plane with TSNE. hint: don't panic, it may take a minute or two to fit.
# normalize them as just like with PCA


word_tsne = TSNE().fit_transform(word_vectors)  # YOUR CODE

# %%
draw_vectors(word_tsne[:, 0], word_tsne[:, 1], color='green', token=words)
# Out:
#   <div id="f140a69f-da9f-4a2e-b553-e0f37c55493f" data-root-id="p1064" style="display: contents;"></div>
# figure(id='p1064', ...)

# %% [markdown]
# ### Visualizing phrases
#
# Word embeddings can also be used to represent short phrases. The simplest way is to take __an average__ of vectors for all tokens in the phrase with some weights.
#
# This trick is useful to identify what data are you working with: find if there are any outliers, clusters or other artifacts.
#
# Let's try this new hammer on our data!

# %%
from torch import mode


def get_phrase_embedding(phrase):
    """
    Convert phrase to a vector by aggregating it's word embeddings. See description above.
    """
    # 1. lowercase phrase
    # 2. tokenize phrase
    # 3. average word vectors for all words in tokenized phrase
    # skip words that are not in model's vocabulary
    # if all words are missing from vocabulary, return zeros

    vector = np.zeros([model.vector_size], dtype='float32')
    tokens = tokenizer.tokenize(phrase.lower())
    valid_vectors = [] 
    for token in tokens:
        if token in model:
            valid_vectors.append(model[token])
    
    if valid_vectors:
        vector = np.mean(valid_vectors, axis=0)
    return vector

# %%
vector = get_phrase_embedding("I'm very sure. This never happened to me before...")

assert np.allclose(vector[::10],
                   np.array([ 0.31807372, -0.02558171,  0.0933293 , -0.1002182 , -1.0278689 ,
                             -0.16621883,  0.05083408,  0.17989802,  1.3701859 ,  0.08655966],
                              dtype=np.float32))
assert np.array_equal(get_phrase_embedding("thisisgibberish"), np.zeros([model.vector_size], dtype='float32')), "corner case for all missing words should be handled as described in the function comments"

# %%
# let's only consider ~5k phrases for a first run.
chosen_phrases = data[::len(data) // 1000]

# compute vectors for chosen phrases
phrase_vectors = np.stack([get_phrase_embedding(phrase) for phrase in chosen_phrases])  # YOUR CODE

# %%
assert isinstance(phrase_vectors, np.ndarray) and np.isfinite(phrase_vectors).all()
assert phrase_vectors.shape == (len(chosen_phrases), model.vector_size)

# %%
# map vectors into 2d space with pca, tsne or your other method of choice
# don't forget to normalize

phrase_vectors_2d = TSNE().fit_transform(phrase_vectors)

phrase_vectors_2d = (phrase_vectors_2d - phrase_vectors_2d.mean(axis=0)) / phrase_vectors_2d.std(axis=0)

# %%
draw_vectors(phrase_vectors_2d[:, 0], phrase_vectors_2d[:, 1],
             phrase=[phrase[:50] for phrase in chosen_phrases],
             radius=20,)
# Out:
#   <div id="f2ff0cb9-6b70-4866-99c0-ad117f166883" data-root-id="p1117" style="display: contents;"></div>
# figure(id='p1117', ...)

# %% [markdown]
# **There's more below! Scroll down when you're ready.**
#
#
# ### Text Classification: Prohibited Comment Classification
#
# ![img](https://github.com/yandexdataschool/nlp_course/raw/master/resources/banhammer.jpg)
#
# __In this notebook__ you will build an algorithm that classifies social media comments into normal or toxic.
# Like in many real-world cases, you only have a small (10^3) dataset of hand-labeled examples to work with. We'll tackle this problem using both classical nlp methods and embedding-based approach.

# %%
# if you're in colab, download the data:
# !wget https://raw.githubusercontent.com/yandexdataschool/nlp_course/refs/heads/2025/week01_embeddings/comments.tsv -O ./comments.tsv -q

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data = pd.read_csv("comments.tsv", sep='\t')

texts = data['comment_text'].values
target = data['should_ban'].values
data[50::200]
# Out:
#      should_ban                                       comment_text
# 50            0  "Those who're in advantageous positions are th...
# 250           1          Fartsalot56 says f**k you motherclucker!!
# 450           1  Are you a fool? \n\nI am sorry, but you seem t...
# 650           1    I AM NOT A VANDAL!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 850           0  Citing sources\n\nCheck out the Wikipedia:Citi...

# %%
from sklearn.model_selection import train_test_split
texts_train, texts_test, y_train, y_test = train_test_split(texts, target, test_size=0.5, random_state=42)

# %% [markdown]
# __Note:__ it is generally a good idea to split data into train/test before anything is done to them.
#
# It guards you against possible data leakage in the preprocessing stage. For example, should you decide to select words present in obscene tweets as features, you should only count those words over the training set. Otherwise your algoritm can cheat evaluation.

# %% [markdown]
# ### Preprocessing and tokenization
#
# Comments contain raw text with punctuation, upper/lowercase letters and even newline symbols.
#
# To simplify all further steps, we'll split text into space-separated tokens using one of nltk tokenizers.

# %%
from nltk.tokenize import TweetTokenizer
tokenizer = TweetTokenizer()
preprocess = lambda text: ' '.join(tokenizer.tokenize(text.lower()))

text = 'How to be a grown-up at work: replace "fuck you" with "Ok, great!".'
print("before:", text,)
print("after:", preprocess(text),)
# Out:
# before: How to be a grown-up at work: replace "fuck you" with "Ok, great!".
# after: how to be a grown-up at work : replace " fuck you " with " ok , great ! " .

# %%
# task: preprocess each comment in train and test

texts_train = [preprocess(text) for text in texts_train]  # YOUR CODE
texts_test = [preprocess(text) for text in texts_test]  # YOUR CODE

# %%
assert texts_train[5] ==  'who cares anymore . they attack with impunity .'
assert texts_test[89] == 'hey todds ! quick q ? why are you so gay'
assert len(texts_test) == len(y_test)

# %% [markdown]
# ### Solving it: bag of words (1 point)
#
# ![img](http://www.novuslight.com/uploads/n/BagofWords.jpg)
#
# One traditional approach to such problem is to use bag of words features:
# 1. build a vocabulary of frequent words (use train data only)
# 2. for each training sample, count the number of times a word occurs in it (for each word in vocabulary).
# 3. consider this count a feature for some classifier
#
# __Note:__ in practice, you can compute such features using sklearn. Please don't do that in the current assignment, though.
# * `from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer`

# %%
# task: find up to k most frequent tokens in texts_train,
# sort them by number of occurrences (highest first)
k = 10000

word_counts = {}
for text in texts_train:
    for word in text.split():
        word_counts[word] = word_counts.get(word, 0) + 1

sorted_words = sorted(word_counts.items(), key=lambda x: x[1], reverse=True)

bow_vocabulary = [word for word, count in sorted_words[:k]]


print('example features:', sorted(bow_vocabulary)[::100])
# Out:
# example features: ['!', '12:20', '300', '_', 'adorned', 'alternative', 'archive', 'average', 'benkner', 'bout', 'came', 'chest', 'combined', 'consumers', 'cricket', 'decisions', 'dickheads', 'domestic', 'eductaion', 'essentially', 'faggot', 'firms', 'frustrated', 'goal', 'hanibal', 'hip-hop', 'identified', 'infoboxes', 'issue', 'kindergarten', 'lets', 'lot', "mclaren's", 'moderator', 'naturally', 'noticeable', 'opposing', 'pdf', 'plant', 'pretoria', 'punctuation', 'rebels', 'repetative', 'riadh', 'schulz', 'shes', 'slit', 'spoof', 'stupid', 't', 'theoretical', 'topic', 'uglyness', 'userspace', 'wanted', 'wikieditor', 'year', '←']

# %%
vocab_to_index = {word: idx for idx, word in enumerate(bow_vocabulary)}

def text_to_bow(text):
    """ convert text string to an array of token counts. Use bow_vocabulary. """
        # Initialize count array with zeros
    bow_vector = np.zeros(len(bow_vocabulary), dtype='float32')
    
    # Tokenize the text
    tokens = text.split()
    
    # Count occurrences of each vocabulary word
    for token in tokens:
        if token in vocab_to_index:
            index = vocab_to_index[token]
            bow_vector[index] += 1
    
    return bow_vector

# %%
X_train_bow = np.stack(list(map(text_to_bow, texts_train)))
X_test_bow = np.stack(list(map(text_to_bow, texts_test)))

# %%
X_train_bow.shape
# Out:
# (500, 5707)

# %%
(len(texts_train), min(k, k_max))
# Out:
# (500, 5707)

# %%
k_max = len(set(' '.join(texts_train).split()))
assert X_train_bow.shape == (len(texts_train), min(k, k_max))
assert X_test_bow.shape == (len(texts_test), min(k, k_max))
assert np.all(X_train_bow[5:10].sum(-1) == np.array([len(s.split()) for s in  texts_train[5:10]]))
assert len(bow_vocabulary) <= min(k, k_max)
assert X_train_bow[6, bow_vocabulary.index('.')] == texts_train[6].split().count('.')

# %% [markdown]
# We shall use a simple linear model: __Logistic Regression__.
# It might not be the fanciest one around, but the simplicity has its own advantages: a linear model is blazingly fast and needs less data to fit.
# Let's sklearn it!

# %%
from sklearn.linear_model import LogisticRegression

bow_model = LogisticRegression(random_state=37, C=0.43)

from sklearn.model_selection import RandomizedSearchCV

param_grid = {
    'C': np.arange(0.1, 2, 0.0001)
}
random_search = RandomizedSearchCV(
    estimator=bow_model,
    param_distributions=param_grid,
    n_iter=60,
    cv=2, 
    scoring='accuracy',
    n_jobs=-1,
    verbose=1
)

# %%
random_search.fit(X_train_bow, y_train)

# Get the best model
bow_model = random_search.best_estimator_
# Out:
# Fitting 2 folds for each of 60 candidates, totalling 120 fits

# %%
random_search.best_params_
# Out:
# {'C': 0.18220000000000236}

# %%
from sklearn.metrics import roc_auc_score, roc_curve


for name, X, y, model in [
    ('train', X_train_bow, y_train, bow_model),
    ('test ', X_test_bow, y_test, bow_model)
]:
    proba = model.predict_proba(X)[:, 1]
    auc = roc_auc_score(y, proba)
    plt.plot(*roc_curve(y, proba)[:2], label='%s AUC=%.4f' % (name, auc))

plt.plot([0, 1], [0, 1], '--', color='black',)
plt.legend(fontsize='large')
plt.grid()

test_accuracy = np.mean(bow_model.predict(X_test_bow) == y_test)
print(f"Model accuracy: {test_accuracy:.3f}")
assert test_accuracy > 0.77, "Hint: tune the parameter C to improve performance"
print("Well done!")
# Out:
# Model accuracy: 0.772
# Well done!

# %% [markdown]
# ### Task: implement TF-IDF features (1 point)
#
# Not all words are equally useful. One can prioritize rare words and downscale words like "and"/"or" by using __tf-idf features__. This abbreviation stands for __text frequency/inverse document frequency__ and means exactly that:
#
# $$ \text{feature}_i = \frac{\text{Count}(word_i \in x)}{\text{Total number of words in } x} \times \log\left(\frac{N}{\text{Count}(word_i \in D) + \alpha}\right) $$
#
#
# , where x is a single text, D is your dataset (a collection of texts), N is a total number of documents and $\alpha$ is a smoothing hyperparameter (typically 1).
# And $Count(word_i \in D)$ is the number of documents where $word_i$ appears.
#
# It may also be a good idea to normalize each data sample after computing tf-idf features.
#
# __Your task:__ implement tf-idf features, train a model and evaluate ROC curve. Compare it with basic BagOfWords model from above.
#
# Please don't use sklearn/nltk built-in tf-idf vectorizers in your solution :) You can still use 'em for debugging though.

# %%
def compute_tfidf_features(texts, vocabulary, alpha=1):
    """
    Compute TF-IDF features for a collection of texts
    
    Args:
        texts: list of preprocessed text strings
        vocabulary: list of words to use as features
        alpha: smoothing parameter for IDF
    
    Returns:
        tfidf_matrix: numpy array of shape (n_texts, n_vocabulary)
    """
    n_texts = len(texts)
    n_vocab = len(vocabulary)
    
    vocab_to_idx = {word: idx for idx, word in enumerate(vocabulary)}
    
    doc_freq = np.zeros(n_vocab, dtype='float32')
    
    for text in texts:
        tokens = set(text.split())
        for token in tokens:
            if token in vocab_to_idx:
                doc_freq[vocab_to_idx[token]] += 1
    
    idf = np.log(n_texts / (doc_freq + alpha))
    tfidf_matrix = np.zeros((n_texts, n_vocab), dtype='float32')
    
    for i, text in enumerate(texts):
        tokens = text.split()
        total_words = len(tokens)
        
        if total_words == 0:
            continue
            
        word_counts = {}
        for token in tokens:
            if token in vocab_to_idx:
                word_counts[token] = word_counts.get(token, 0) + 1
        
        for word, count in word_counts.items():
            idx = vocab_to_idx[word]
            tf = count / total_words  # Term Frequency
            tfidf_matrix[i, idx] = tf * idf[idx]
        
        norm = np.linalg.norm(tfidf_matrix[i])
        if norm > 0:
            tfidf_matrix[i] /= norm
    
    return tfidf_matrix

def text_to_tfidf(text, vocabulary, idf_vector, alpha=1):
    """
    Convert a single text to TF-IDF vector
    
    Args:
        text: input text string
        vocabulary: list of words
        idf_vector: precomputed IDF values
        alpha: smoothing parameter
    
    Returns:
        tfidf_vector: numpy array of TF-IDF features
    """
    n_vocab = len(vocabulary)
    vocab_to_idx = {word: idx for idx, word in enumerate(vocabulary)}
    
    tfidf_vector = np.zeros(n_vocab, dtype='float32')
    
    tokens = text.split()
    total_words = len(tokens)
    
    if total_words == 0:
        return tfidf_vector
    
    word_counts = {}
    for token in tokens:
        if token in vocab_to_idx:
            word_counts[token] = word_counts.get(token, 0) + 1
    
    for word, count in word_counts.items():
        idx = vocab_to_idx[word]
        tf = count / total_words
        tfidf_vector[idx] = tf * idf_vector[idx]
    
    norm = np.linalg.norm(tfidf_vector)
    if norm > 0:
        tfidf_vector /= norm
    
    return tfidf_vector

# %%
X_train_tfidf = compute_tfidf_features(texts_train, bow_vocabulary)

tfidf_model = LogisticRegression(random_state=37, C=0.43)
random_search = RandomizedSearchCV(
    estimator=tfidf_model,
    param_distributions=param_grid,
    n_iter=60,
    cv=2, 
    scoring='accuracy',
    n_jobs=-1,
    verbose=1
)

random_search.fit(X_train_bow, y_train)

tfidf_model = random_search.best_estimator_
# Out:
# Fitting 2 folds for each of 60 candidates, totalling 120 fits

# %%
from sklearn.metrics import roc_auc_score, roc_curve


for name, X, y, model in [
    ('train_bow', X_train_bow, y_train, bow_model),
    ('test_bow ', X_test_bow, y_test, bow_model),
    ('train_tf_idf', X_train_bow, y_train, tfidf_model),
    ('test_tf_idf ', X_test_bow, y_test, tfidf_model),
]:
    proba = model.predict_proba(X)[:, 1]
    auc = roc_auc_score(y, proba)
    plt.plot(*roc_curve(y, proba)[:2], label='%s AUC=%.4f' % (name, auc))

plt.plot([0, 1], [0, 1], '--', color='black',)
plt.legend(fontsize='large')
plt.grid()

test_bow_accuracy = np.mean(bow_model.predict(X_test_bow) == y_test)
test_tf_idf_accuracy = np.mean(tfidf_model.predict(X_test_bow) == y_test)
print(f"bow accuracy : {test_bow_accuracy:.3f}")
print(f"tfidf accuracy : {test_tf_idf_accuracy:.3f}")
print("Well done!")
# Out:
# bow accuracy : 0.772
# tfidf accuracy : 0.774
# Well done!

# %% [markdown]
# Scroll down when you're done with TF-IDF!
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
#
# ### Solving it better: word vectors (1 point)
#
# Let's try another approach: instead of counting per-word frequencies, we shall map all words to pre-trained word vectors and average over them to get text features.
#
# This should give us two key advantages: (1) we now have 10^2 features instead of 10^4 and (2) our model can generalize to word that are not in training dataset.
#
# We begin with a standard approach with pre-trained word vectors. However, you may also try
# * training embeddings from scratch on relevant (unlabeled) data
# * multiplying word vectors by inverse word frequency in dataset (like tf-idf).
# * concatenating several embeddings
#     * call `gensim.downloader.info()['models'].keys()` to get a list of available models
# * clusterizing words by their word-vectors and try bag of cluster_ids
#
# __Note:__ loading pre-trained model may take a while. It's a perfect opportunity to refill your cup of tea/coffee and grab some extra cookies. Or binge-watch some tv series if you're slow on internet connection

# %%
import gensim.downloader
embeddings = gensim.downloader.load("fasttext-wiki-news-subwords-300")

# If you're low on RAM or download speed, use "glove-wiki-gigaword-100" instead. Ignore all further asserts.
# Out:
# [==================================================] 100.0% 958.5/958.4MB downloaded

# %%
def vectorize_sum(comment):
    """
    implement a function that converts preprocessed comment to a sum of token vectors
    """
    embedding_dim = embeddings.vectors.shape[1]
    features = np.zeros([embedding_dim], dtype='float32')
    
    # YOUR CODE
    tokens = comment.split()
    
    for token in tokens:
        if token in embeddings.key_to_index: 
            features += embeddings[token]
    return features

assert np.allclose(
    vectorize_sum("who cares anymore . they attack with impunity .")[::70],
    np.array([ 0.0108616 ,  0.0261663 ,  0.13855131, -0.18510573, -0.46380025])
)

# %%
X_train_wv = np.stack([vectorize_sum(text) for text in texts_train])
X_test_wv = np.stack([vectorize_sum(text) for text in texts_test])

# %%
wv_model = LogisticRegression().fit(X_train_wv, y_train)

for name, X, y, model in [
    ('bow train', X_train_bow, y_train, bow_model),
    ('bow test ', X_test_bow, y_test, bow_model),
    ('vec train', X_train_wv, y_train, wv_model),
    ('vec test ', X_test_wv, y_test, wv_model)
]:
    proba = model.predict_proba(X)[:, 1]
    auc = roc_auc_score(y, proba)
    plt.plot(*roc_curve(y, proba)[:2], label='%s AUC=%.4f' % (name, auc))

plt.plot([0, 1], [0, 1], '--', color='black',)
plt.legend(fontsize='large')
plt.grid()

assert roc_auc_score(y_test, wv_model.predict_proba(X_test_wv)[:, 1]) > 0.92, "something's wrong with your features"
# Out:
# /home/home/ShadProjects/nlp_course/.venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# If everything went right, you've just managed to reduce misclassification rate by a factor of two.
# This trick is very useful when you're dealing with small datasets. However, if you have hundreds of thousands of samples, there's a whole different range of methods for that. We'll get there in the second part.
#
# **Would you like to know more?**
# * See what other embeddings are there in the model zoo: `gensim.downloader.info()`
# * Take a look at [FastText embeddings](https://github.com/facebookresearch/fastText)
